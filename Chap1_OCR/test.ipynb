# %%
import sys
sys.path.insert(1, '/home/furqan/.pyenv/versions/3.8.5/lib/python3.8/site-packages')

import albumentations
import torch

import os
import glob
import numpy as np
from sklearn import model_selection

from PIL import Image
from PIL import ImageFile

ImageFile.LOAD_TRUNCATED_IMAGES = True

# %%
class ClassificationDataset:
    def __init__(self, image_paths, targets, resize=None):
        # resize = (height, width)
        self.image_paths = image_paths
        self.targets = targets
        self.resize = resize

        mean = (0.485, 0.456, 0.406)
        std = (0.229, 0.224, 0.225)
         # albumentations is relatd to augmenting the image, such as resizing, rotating and normalizing etc.
        self.aug = albumentations.Compose(
            [
                albumentations.Normalize(
                    mean, std, max_pixel_value=255.0, always_apply=True
                )
            ]
        )

    def __len__(self):
        return len(self.image_paths)

    def __getitem__(self, item):
        image = Image.open(self.image_paths[item]).convert("RGB")
        targets = self.targets[item]

        if self.resize is not None:
            image = image.resize(
                (self.resize[1], self.resize[0]), resample=Image.BILINEAR
            )

        image = np.array(image)
        augmented = self.aug(image=image)
        image = augmented["image"]
        # transpose is used to bring the channels dim first and width and height later. 
        image = np.transpose(image, (2, 0, 1)).astype(np.float32)

        return {
            "images": torch.tensor(image, dtype=torch.float),
            "targets": torch.tensor(targets, dtype=torch.long),
        }

# %%
dataset_path = "/home/furqan/Desktop/python_work/My_udemy_course/Chap1_OCR/captcha_images_v2"
image_files = glob.glob(os.path.join(dataset_path, "*.png"))

print(image_files)
# dataset = ClassificationDataset(image_path=dataset_path, )
# Out:
# ['/home/furqan/Desktop/python_work/My_udemy_course/Chap1_OCR/captcha_images_v2/nf2n8.png', '/home/furqan/Desktop/python_work/My_udemy_course/Chap1_OCR/captcha_images_v2/537nf.png', '/home/furqan/Desktop/python_work/My_udemy_course/Chap1_OCR/captcha_images_v2/defyx.png', '/home/furqan/Desktop/python_work/My_udemy_course/Chap1_OCR/captcha_images_v2/m3b5p.png', '/home/furqan/Desktop/python_work/My_udemy_course/Chap1_OCR/captcha_images_v2/dyxnc.png', '/home/furqan/Desktop/python_work/My_udemy_course/Chap1_OCR/captcha_images_v2/fyfbn.png', '/home/furqan/Desktop/python_work/My_udemy_course/Chap1_OCR/captcha_images_v2/3cpwb.png', '/home/furqan/Desktop/python_work/My_udemy_course/Chap1_OCR/captcha_images_v2/nxx25.png', '/home/furqan/Desktop/python_work/My_udemy_course/Chap1_OCR/captcha_images_v2/n5x2n.png', '/home/furqan/Desktop/python_work/My_udemy_course/Chap1_OCR/captcha_images_v2/wye85.png', '/home/furqan/Desktop/python_work/My_udemy_course/Chap1_OCR/captcha_images_v2/2w4y7.png', '/home/furqan/Desktop/python_work/My_udemy_course/Chap1_OCR/captcha_images_v2/xe8xm.png', '/home/furqan/Desktop/python_work/My_udemy_course/Chap1_OCR/captcha_images_v2/6cm6m.png', '/home/furqan/Desktop/python_work/My_udemy_course/Chap1_OCR/captcha_images_v2/8npe3.png', '/home/furqan/Desktop/python_work/My_udemy_course/Chap1_OCR/captcha_images_v2/wc2bd.png', '/home/furqan/Desktop/python_work/My_udemy_course/Chap1_OCR/captcha_images_v2/68x48.png', '/home/furqan/Desktop/python_work/My_udemy_course/Chap1_OCR/captcha_images_v2/pcm7f.png', '/home/furqan/Desktop/python_work/My_udemy_course/Chap1_OCR/captcha_images_v2/36nx4.png', '/home/furqan/Desktop/python_work/My_udemy_course/Chap1_OCR/captcha_images_v2/f2m8n.png', '/home/furqan/Desktop/python_work/My_udemy_course/Chap1_OCR/captcha_images_v2/mxnw4.png', '/home/furqan/Desktop/python_work/My_udemy_course/Chap1_OCR/captcha_images_v2/f858x.png', '/home/furqan/Desktop/python_work/My_udemy_course/Chap1_OCR/captcha_images_v2/8g4yp.png', '/home/furqan/Desktop/python_work/My_udemy_course/Chap1_OCR/captcha_images_v2/3nfdn.png', '/home/furqan/Desktop/python_work/My_udemy_course/Chap1_OCR/captcha_images_v2/fp3wy.png', '/home/furqan/Desktop/python_work/My_udemy_course/Chap1_OCR/captcha_images_v2/bd3b7.png', '/home/furqan/Desktop/python_work/My_udemy_course/Chap1_OCR/captcha_images_v2/w75w8.png', '/home/furqan/Desktop/python_work/My_udemy_course/Chap1_OCR/captcha_images_v2/dpbyd.png', '/home/furqan/Desktop/python_work/My_udemy_course/Chap1_OCR/captcha_images_v2/7m8px.png', '/home/furqan/Desktop/python_work/My_udemy_course/Chap1_OCR/captcha_images_v2/28348.png', '/home/furqan/Desktop/python_work/My_udemy_course/Chap1_OCR/captcha_images_v2/865wm.png', '/home/furqan/Desktop/python_work/My_udemy_course/Chap1_OCR/captcha_images_v2/b35f6.png', '/home/furqan/Desktop/python_work/My_udemy_course/Chap1_OCR/captcha_images_v2/5nm6d.png', '/home/furqan/Desktop/python_work/My_udemy_course/Chap1_OCR/captcha_images_v2/7fde7.png', '/home/furqan/Desktop/python_work/My_udemy_course/Chap1_OCR/captcha_images_v2/p8wwf.png', '/home/furqan/Desktop/python_work/My_udemy_course/Chap1_OCR/captcha_images_v2/yyn57.png', '/home/furqan/Desktop/python_work/My_udemy_course/Chap1_OCR/captcha_images_v2/mgw3n.png', '/home/furqan/Desktop/python_work/My_udemy_course/Chap1_OCR/captcha_images_v2/2npg6.png', '/home/furqan/Desktop/python_work/My_udemy_course/Chap1_OCR/captcha_images_v2/4n2yg.png', '/home/furqan/Desktop/python_work/My_udemy_course/Chap1_OCR/captcha_images_v2/c6745.png', '/home/furqan/Desktop/python_work/My_udemy_course/Chap1_OCR/captcha_images_v2/x76mn.png', '/home/furqan/Desktop/python_work/My_udemy_course/Chap1_OCR/captcha_images_v2/d378n.png', '/home/furqan/Desktop/python_work/My_udemy_course/Chap1_OCR/captcha_images_v2/b2g8e.png', '/home/furqan/Desktop/python_work/My_udemy_course/Chap1_OCR/captcha_images_v2/bpwd7.png', '/home/furqan/Desktop/python_work/My_udemy_course/Chap1_OCR/captcha_images_v2/xxw44.png', '/home/furqan/Desktop/python_work/My_ud ...

# %%
for i in image_files:
    j = i.split("/")
    print(j[-1][:-4])
# Out:
# nf2n8
# 537nf
# defyx
# m3b5p
# dyxnc
# fyfbn
# 3cpwb
# nxx25
# n5x2n
# wye85
# 2w4y7
# xe8xm
# 6cm6m
# 8npe3
# wc2bd
# 68x48
# pcm7f
# 36nx4
# f2m8n
# mxnw4
# f858x
# 8g4yp
# 3nfdn
# fp3wy
# bd3b7
# w75w8
# dpbyd
# 7m8px
# 28348
# 865wm
# b35f6
# 5nm6d
# 7fde7
# p8wwf
# yyn57
# mgw3n
# 2npg6
# 4n2yg
# c6745
# x76mn
# d378n
# b2g8e
# bpwd7
# xxw44
# n7ebx
# 3ym7f
# f2fge
# n6xc5
# mxyxw
# xyncc
# ddmyg
# yf424
# nfbg8
# 7dgc2
# 6dd2y
# 5bgp2
# 5nxnn
# nbfx5
# 662bw
# cewnm
# m2576
# nc4yg
# dn2ym
# ef4np
# 33p4e
# x6pdb
# gnbn4
# 268g2
# 23n88
# 88y52
# 728n8
# b5dn4
# e84n2
# b84xc
# ecd4w
# e6b7y
# wd2gb
# f35xp
# mg5nn
# b5nmm
# exycn
# 7g3nf
# 8n62n
# 3x5fm
# e7nx4
# 6bxwg
# y5n6d
# x3fwf
# c7nn8
# xfn6n
# 3ygde
# n464c
# e46yw
# 8bbw8
# deep5
# 4gb3f
# pyefb
# 5nggg
# 5nnff
# bnc5f
# 6wb76
# gfp54
# m3wfw
# 34fxm
# dn26n
# 658xe
# 6e2dg
# mn5c4
# 7wyp4
# bny23
# mc35n
# 5p3mm
# 5n3w4
# p2x7x
# p2m6n
# nf7bn
# n3bm6
# x38fn
# dd5w5
# ypp8f
# 264m5
# wgnwp
# gy8xb
# fy2nd
# nnn5p
# yy824
# xf5g7
# pnmxf
# 428b6
# 3n2b4
# 3d7bd
# 6fg8c
# be6np
# x362g
# 23mdg
# p57fn
# bbymy
# 6n5fd
# gc83b
# pg4bf
# xw465
# bw5nf
# ppx77
# 7e2y7
# 47m2b
# d7nn3
# xyyyw
# g3ex3
# ndecc
# dmx8p
# 8xef7
# 8cm46
# 5ng6e
# 57b27
# c8n8c
# ny3dw
# een23
# 7yf62
# 8d4wm
# nd5wg
# wm746
# 4w76g
# fywb8
# bm3p8
# gfxcc
# wnpec
# ppwyd
# x8e8n
# 4ynf3
# 226md
# cd4eg
# 44ype
# 8d2nd
# nwg2m
# n2gmg
# cd6p4
# m448b
# mm3nn
# 823p2
# pf4nb
# p5nce
# 82fx2
# 2356g
# ydg8n
# n3m6x
# fnbfw
# 3xcgg
# 488de
# ec6pm
# b55d6
# xngxc
# dn5df
# md344
# pdcp4
# 8eggg
# 36w25
# 3p67n
# 6bdn5
# 8d8ep
# cdfen
# mcg43
# nfcb5
# gd4mf
# 244e2
# 5n728
# ne325
# e2d66
# d4ppy
# c4bny
# 6xxdx
# 6end3
# c86md
# w2yp7
# ygfwe
# 7dxbd
# pp546
# xgcxy
# pwmbn
# 6pfy4
# g2fnw
# bgb48
# x74b2
# dy3cx
# nfg23
# dmxp8
# 8np22
# n373n
# f5e5e
# x5nyn
# m2nf4
# gm6nn
# ymp7g
# pmf5w
# 5bg8f
# 74853
# c2fb7
# w6pxy
# 5bb66
# 75pfw
# bp2d4
# 5expp
# m8gmx
# dcnp8
# 4gycb
# 6wg4n
# fcmem
# npxb7
# n7enn
# y5dpp
# c753e
# 68wfd
# px8n8
# 64b3p
# b28g8
# 2mpnn
# yg5bb
# 84w7x
# 43gey
# ddcdd
# cm6yb
# f85y3
# b4y5x
# 2x7bm
# y3c58
# 8n2pg
# 6ng6w
# nny5e
# 77387
# gxxpf
# xwx7d
# dce8y
# ny5dp
# byc82
# 7mgmf
# 8gmnx
# 6m5eg
# 63824
# 88bgx
# 785n4
# ybfx6
# 2xc2n
# e25xg
# 8n34n
# 7bb7b
# 4cfw8
# yemy4
# 43p5d
# mcc2x
# bny4w
# 7dwx4
# xcf88
# mmy5n
# 72m6f
# mpxfb
# gnf85
# d75b5
# w8f36
# 76nxn
# y4g3b
# pp87n
# 6wnyc
# 6e554
# 2n73f
# bc8nf
# 43xfe
# 7xcyd
# ddnpf
# 4exnn
# 7b4bm
# neecd
# x4f7g
# e76n4
# enn7n
# 3x325
# 664nf
# cx3wg
# 6n6gg
# g55b4
# d3ycn
# 7wn74
# 245y5
# bdg84
# pym7p
# 646x8
# n8pfe
# y53c2
# xxney
# 4cn7b
# mmc5n
# xce8d
# e2mg2
# x277e
# 8nbew
# 55w5c
# 24f6w
# 3nnpw
# dw8d3
# xcmbp
# cfc56
# 85622
# 5np4m
# de45x
# 6f857
# 44xe8
# b43nw
# nb267
# ef4mn
# x7547
# 6b46g
# byfgn
# yd755
# nwfde
# 7cgym
# yf28d
# cfp86
# ncyx8
# 87nym
# cwmny
# pbpgc
# n5wbg
# bcwnn
# p8ngx
# mbp2y
# 65ebm
# xnnc3
# nbwnn
# y2xg4
# pwebm
# pcpg6
# 44fyb
# 6c3p5
# fc2ff
# 2nbcx
# cwgyx
# p4pde
# 2mg87
# ffd6p
# wce5n
# e43ym
# nn4wx
# g7wxw
# cy3nw
# e46pd
# yxd7m
# mwxwp
# bgd4m
# 43mn5
# c55c6
# nbwpn
# w2e87
# c43b4
# gcfgp
# 77n6g
# wb3ed
# mggce
# n4b4m
# mye68
# de7f8
# 8npd5
# 33n73
# m4g8g
# 573bn
# ng2gw
# ny3nn
# 5x5nx
# f8f8g
# 85dxn
# n6f4b
# mp7wp
# 8n4n8
# bf52c
# 7gce6
# nm46n
# bp6mw
# 6c3n6
# 6ecbn
# c8fxy
# x7746
# 5xwcg
# y866y
# 4d22m
# 65m85
# 73mnx
# 4yc85
# 678w3
# 445cc
# ncfgb
# b2nen
# 5dxnm
# gecmf
# x3deb
# f83pn
# 2nf26
# m74dm
# 6gnm3
# f4fn2
# 373gb
# 5ep3n
# befbd
# bgem5
# 6p7gx
# d7en3
# wmpmp
# 2enf4
# 2g7nm
# b5fm7
# c5xne
# x775w
# d22y5
# y5w28
# x4pnp
# 8cccc
# mnef5
# m22e3
# 34b84
# nxxf8
# 4m2w5
# nw5b2
# cnex4
# 5n245
# fc6xb
# pw5nc
# g888x
# 3bnyf
# ee8fg
# 6mygb
# cdmn8
# gm7n8
# 8wy7d
# 7xd5m
# nwncn
# ncw4g
# fcey3
# g7gnf
# en4n4
# 2gyb6
# 33f7m
# 2cgyx
# x7422
# edg3p
# 8y6b3
# 2b827
# f6ww8
# 325fb
# mb4en
# my84e
# nnp4e
# 37ep6
# 36bc2
# gny6b
# cb8cf
# fbp2c
# c3572
# 3bd8f
# cpe63
# n265y
# 6ydyp
# cg5dd
# p5g5m
# yeyn4
# 56c34
# c3n8x
# fw3b2
# e72cd
# gegw4
# yw667
# p4nm4
# mdyp7
# 25w53
# 74eyg
# yyg5g
# wfy5m
# 8w875
# gymmn
# x458w
# g8gnd
# efg72
# 5fyem
# 42xpy
# mddgb
# ewnx8
# 8684m
# n8ydd
# 8w754
# 6n443
# 6e6pn
# p8c24
# 2g783
# mc8w2
# 8pfxx
# 2fxgd
# ndg2b
# 7cdge
# n5cm7
# 3wnd3
# ndme7
# n3x4c
# xf4p4
# b5pnn
# nmw46
# b685n
# 677g3
# 5npdn
# xp24p
# ng756
# fp382
# w4nfx
# 66wp5
# 7p852
# 4dgf7
# pdyc8
# f4wfn
# cpc8c
# d236n
# 6f2yc
# wyc25
# c353e
# 4n3mn
# m5ym2
# men4f
# 6mn8n
# bw6n6
# nngxc
# 6cwxe
# m3588
# 4b2pw
# p2ym2
# 67dey
# x347n
# gbxyy
# d7c5x
# 8n5p3
# 7gmf3
# ffpxf
# g7fmc
# 664dn
# nnn57
# yew6p
# nfndw
# bw44w
# nbf8m
# 7f8b3
# gc277
# 78eec
# dyp7n
# 2nx38
# d3c7y
# gn2xy
# 3den6
# dbpcd
# y7x8p
# 5g5e5
# gcx6f
# 4ycex
# 28x47
# 7nnnx
# gewfy
# 55y2m
# 6ng6n
# 2wx73
# wg625
# gd8fb
# 56ncx
# n3ffn
# gp22x
# 58pnp
# n7meb
# fp762
# w4cnn
# efx34
# d8xcn
# yw7ny
# pg2yx
# 8n65n
# 832f3
# d2nbn
# 2bg48
# b4d7c
# 46mbm
# gnc3n
# ennmm
# 57gnx
# n4xx5
# d22n7
# d3c8y
# 253dc
# d6fcn
# cfn53
# 7wnpm
# w52fn
# dnmd8
# 8y63f
# fxpw3
# cfc2y
# 3nw7w
# ccf2w
# gwn53
# 32dnn
# nf8b8
# y33nm
# c4bgd
# xnn4d
# 6g45w
# cffp4
# mmg2m
# xfg65
# wxcn8
# 3fbxd
# dbfen
# 22d5n
# e5n66
# pgg3n
# 25m6p
# pgmn2
# y5g87
# pcede
# m67b3
# e8dxn
# xc68n
# x5f54
# gy433
# dbny3
# c4527
# wf684
# m6n4x
# dw6mn
# gng6e
# e4gd7
# 53mn8
# 33ng4
# 3bx86
# b4ncn
# b3xpn
# bwmee
# cdcb3
# gy5bf
# 387g2
# 3bfnd
# mpmy5
# 6xpme
# xbcbx
# 5f3gf
# 76y6f
# 8nn73
# cgcgb
# 3eny7
# 52447
# dxwcw
# 5p8fm
# n4wwn
# ycnfc
# 368y5
# wm47f
# xe6eb
# pyf65
# fpw76
# cnmnn
# efb3f
# m8m4x
# nnf8b
# ndyfe
# myc3c
# n7dyb
# pg2pm
# n336e
# wdww8
# wxy4n
# yfdn7
# mx8bb
# 474ff
# 4fp5g
# 5n732
# deneb
# pmg55
# mmfm6
# f753f
# n7ff2
# f75cx
# ebcbx
# pxne8
# 8db67
# g3dy6
# be3bp
# 7dyww
# b6f2p
# 3b4we
# 8n56m
# x44n4
# 2cegf
# gp7c5
# d8dce
# 42dw4
# ewcf5
# w8bnx
# 6mege
# 8gmc4
# e6m6p
# d666m
# 62nb3
# 5325m
# dnxdp
# fcne6
# 8gf7n
# ggd7m
# bw5ym
# pe4xn
# by5y3
# nb45d
# 7pcd7
# 5yxgp
# dd764
# ccn2x
# 3w2bw
# xnfx5
# 64m82
# 3n3cf
# 3ye2e
# 3pe4g
# 556wd
# ngn26
# 5bnd7
# 8fexn
# pxdwp
# fg8n4
# 44c22
# nfd8g
# w46ep
# 6p2ge
# p24gn
# y4ec2
# 77wp4
# 37d52
# b26nd
# c4mcm
# pgwnp
# gc2wd
# ng6yp
# 8bbm4
# xfgxb
# 2cg58
# x8xnp
# 8c2wy
# ny8np
# enpw2
# 6bnnm
# g842c
# g247w
# wddcp
# 63pxe
# ep85x
# 2wc38
# nxcmn
# m457d
# g78gn
# e7x45
# x2cnn
# mfc35
# m5meg
# 3ebpw
# c2g4d
# xdn65
# xnd3y
# ypw3d
# c482b
# 675p3
# yx2d4
# neggn
# 8ne4g
# fwxdp
# c6we6
# 5ywwf
# y7mnm
# 4743p
# 3p4nn
# mgdwb
# dbex3
# y2436
# 5x7x5
# e667x
# wwmn6
# bxxfc
# 7fmcy
# x4gg5
# fncnb
# 47e4p
# 6dmx7
# egxmp
# gm2c2
# 8e32m
# fg38b
# y2ye8
# excmn
# wbncw
# 7gnge
# ygenn
# yd3m3
# 7bwm2
# wnmyn
# nm248
# 3g2w6
# nbmx7
# 5mcy7
# c6f8g
# 6pwcn
# 6fn84
# eppg3
# 6b4w6
# ng46m
# gw53m
# 2ycn8
# 3ny45
# pm363
# n2by7
# f22bn
# bnc2f
# ddpyb
# pdw38
# bdbb3
# en32e
# 5mgn4
# w7e6m
# xmcym
# 57wdp
# n8fp6
# m75bf
# f228n
# 8ypdn
# 25257
# 38n57
# e3ndn
# wecfd
# 4c8n8
# bmxpe
# 3dgmf
# 6825y
# mbf58
# 5wddw
# n4cpy
# cen55
# 7634y
# n5w5g
# cc845
# w4x2m
# nnfx3
# 5xd2e
# w6yne
# x37bf
# y4n6m
# ycmcw
# ddcne
# mmg38
# dmw8n
# 7y2x4
# xemyg
# cfw6e
# nfcwy
# gdng3
# 4nnf3
# cdf77
# 87d4c
# w48cw
# 3n7mx
# 5mf7c
# 8n5pn
# dw3nn
# 5pm6b
# 33b22
# 3ebnn
# d22bd
# 2yggg
# 58b5m
# 4egem
# nbcgb
# y7d75
# 32cnn
# e8e5e
# f5cm2
# 4dw3w
# xbem6
# pf5ng
# ydd3g
# pm47f
# nxc83
# efgx5
# n6nn2
# d4n82
# 2pfpn
# gwnm6
# 7w67m
# 5gcd3
# gf2g4
# 3xng6
# mfb3x
# c7gb3
# 378e5
# x6b5m
# eng53
# bn5mw
# 2en7g
# w2n7e
# mdxpn
# 574d7
# 6ge3p
# 5mfff
# 8gecm
# gpnxn
# pmd3w
# 3mxdn
# 8b735
# ffnxn
# 3ndxd
# 8c23f
# 6xen4
# gw468
# f364x
# m4fd8
# pnnwy
# fp5wn
# cwdnx
# efe62
# nbp3e
# c2pg6
# px2xp
# 573d8
# nybcx
# mcyfx
# nxn4f
# f6ne5
# 34pcn
# 76353
# myf82
# pwn5e
# c2yn8
# ywn6f
# cnwyc
# dnne7
# gxx2p
# 2p2y8
# pgm2e
# fdpgd
# pme86
# 56m6y
# mwdf6
# nmy2x
# 4nc37
# 377xx
# 7gp47
# n5n8b
# 4fc36
# 25p2m
# y32yy
# dfnx4
# feyc8
# 5mnpd
# p2dw7
# xxbm5
# xdcn4
# fg7mg
# gfbx6
# edwny
# nn6mg
# 478nx
# gnbde
# f74x3
# 4f8yp
# p7fyp
# d2ycw
# 76n7p
# d66cn
# 25egp
# 53wb8
# gn2d3
# 53wp3
# dc436
# w4cdc
# 42nxy
# 4433m
# xymfn
# 4w6mw
# yd38e
# gpxng
# yf347
# 24pew
# 243mm
# ncww7
# g2577
# emwpn
# g6n7x
# 6fgdw
# mw5p2
# p6mn8
# n7g4f
# 7pn5g
# pybee
# 467d5
# pn7pn
# y48c3
# m23bp
# f7cey
# 7d44m

# %%
targets_orig = [i.split("/")[-1][:-4] for i in image_files]

# %%
targets_orig
# Out:
# ['nf2n8',
#  '537nf',
#  'defyx',
#  'm3b5p',
#  'dyxnc',
#  'fyfbn',
#  '3cpwb',
#  'nxx25',
#  'n5x2n',
#  'wye85',
#  '2w4y7',
#  'xe8xm',
#  '6cm6m',
#  '8npe3',
#  'wc2bd',
#  '68x48',
#  'pcm7f',
#  '36nx4',
#  'f2m8n',
#  'mxnw4',
#  'f858x',
#  '8g4yp',
#  '3nfdn',
#  'fp3wy',
#  'bd3b7',
#  'w75w8',
#  'dpbyd',
#  '7m8px',
#  '28348',
#  '865wm',
#  'b35f6',
#  '5nm6d',
#  '7fde7',
#  'p8wwf',
#  'yyn57',
#  'mgw3n',
#  '2npg6',
#  '4n2yg',
#  'c6745',
#  'x76mn',
#  'd378n',
#  'b2g8e',
#  'bpwd7',
#  'xxw44',
#  'n7ebx',
#  '3ym7f',
#  'f2fge',
#  'n6xc5',
#  'mxyxw',
#  'xyncc',
#  'ddmyg',
#  'yf424',
#  'nfbg8',
#  '7dgc2',
#  '6dd2y',
#  '5bgp2',
#  '5nxnn',
#  'nbfx5',
#  '662bw',
#  'cewnm',
#  'm2576',
#  'nc4yg',
#  'dn2ym',
#  'ef4np',
#  '33p4e',
#  'x6pdb',
#  'gnbn4',
#  '268g2',
#  '23n88',
#  '88y52',
#  '728n8',
#  'b5dn4',
#  'e84n2',
#  'b84xc',
#  'ecd4w',
#  'e6b7y',
#  'wd2gb',
#  'f35xp',
#  'mg5nn',
#  'b5nmm',
#  'exycn',
#  '7g3nf',
#  '8n62n',
#  '3x5fm',
#  'e7nx4',
#  '6bxwg',
#  'y5n6d',
#  'x3fwf',
#  'c7nn8',
#  'xfn6n',
#  '3ygde',
#  'n464c',
#  'e46yw',
#  '8bbw8',
#  'deep5',
#  '4gb3f',
#  'pyefb',
#  '5nggg',
#  '5nnff',
#  'bnc5f',
#  '6wb76',
#  'gfp54',
#  'm3wfw',
#  '34fxm',
#  'dn26n',
#  '658xe',
#  '6e2dg',
#  'mn5c4',
#  '7wyp4',
#  'bny23',
#  'mc35n',
#  '5p3mm',
#  '5n3w4',
#  'p2x7x',
#  'p2m6n',
#  'nf7bn',
#  'n3bm6',
#  'x38fn',
#  'dd5w5',
#  'ypp8f',
#  '264m5',
#  'wgnwp',
#  'gy8xb',
#  'fy2nd',
#  'nnn5p',
#  'yy824',
#  'xf5g7',
#  'pnmxf',
#  '428b6',
#  '3n2b4',
#  '3d7bd',
#  '6fg8c',
#  'be6np',
#  'x362g',
#  '23mdg',
#  'p57fn',
#  'bbymy',
#  '6n5fd',
#  'gc83b',
#  'pg4bf',
#  'xw465',
#  'bw5nf',
#  'ppx77',
#  '7e2y7',
#  '47m2b',
#  'd7nn3',
#  'xyyyw',
#  'g3ex3',
#  'ndecc',
#  'dmx8p',
#  '8xef7',
#  '8cm46',
#  '5ng6e',
#  '57b27',
#  'c8n8c',
#  'ny3dw',
#  'een23',
#  '7yf62',
#  '8d4wm',
#  'nd5wg',
#  'wm746',
#  '4w76g',
#  'fywb8',
#  'bm3p8',
#  'gfxcc',
#  'wnpec',
#  'ppwyd',
#  'x8e8n',
#  '4ynf3',
#  '226md',
#  'cd4eg',
#  '44ype',
#  '8d2nd',
#  'nwg2m',
#  'n2gmg',
#  'cd6p4',
#  'm448b',
#  'mm3nn',
#  '823p2',
#  'pf4nb',
#  'p5nce',
#  '82fx2',
#  '2356g',
#  'ydg8n',
#  'n3m6x',
#  'fnbfw',
#  '3xcgg',
#  '488de',
#  'ec6pm',
#  'b55d6',
#  'xngxc',
#  'dn5df',
#  'md344',
#  'pdcp4',
#  '8eggg',
#  '36w25',
#  '3p67n',
#  '6bdn5',
#  '8d8ep',
#  'cdfen',
#  'mcg43',
#  'nfcb5',
#  'gd4mf',
#  '244e2',
#  '5n728',
#  'ne325',
#  'e2d66',
#  'd4ppy',
#  'c4bny',
#  '6xxdx',
#  '6end3',
#  'c86md',
#  'w2yp7',
#  'ygfwe',
#  '7dxbd',
#  'pp546',
#  'xgcxy',
#  'pwmbn',
#  '6pfy4',
#  'g2fnw',
#  'bgb48',
#  'x74b2',
#  'dy3cx',
#  'nfg23',
#  'dmxp8',
#  '8np22',
#  'n373n',
#  'f5e5e',
#  'x5nyn',
#  'm2nf4',
#  'gm6nn',
#  'ymp7g',
#  'pmf5w',
#  '5bg8f',
#  '74853',
#  'c2fb7',
#  'w6pxy',
#  '5bb66',
#  '75pfw',
#  'bp2d4',
#  '5expp',
#  'm8gmx',
#  'dcnp8',
#  '4gycb',
#  '6wg4n',
#  'fcmem',
#  'npxb7',
#  'n7enn',
#  'y5dpp',
#  'c753e',
#  '68wfd',
#  'px8n8',
#  '64b3p',
#  'b28g8',
#  '2mpnn',
#  'yg5bb',
#  '84w7x',
#  '43gey',
#  'ddcdd',
#  'cm6yb',
#  'f85y3',
#  'b4y5x',
#  '2x7bm',
#  'y3c58',
#  '8n2pg',
#  '6ng6w',
#  'nny5e',
#  '77387',
#  'gxxpf',
#  'xwx7d',
#  'dce8y',
#  'ny5dp',
#  'byc82',
#  '7mgmf',
#  '8gmnx',
#  '6m5eg',
#  '63824',
#  '88bgx',
#  '785n4',
#  'ybfx6',
#  '2xc2n',
#  'e25xg',
#  '8n34n',
#  '7bb7b',
#  '4cfw8',
#  'yemy4',
#  '43p5d',
#  'mcc2x',
#  'bny4w',
#  '7dwx4',
#  'xcf88',
#  'mmy5n',
#  '72m6f',
#  'mpxfb',
#  'gnf85',
#  'd75b5',
#  'w8f36',
#  '76nxn',
#  'y4g3b',
#  'pp87n',
#  '6wnyc',
#  '6e554',
#  '2n73f',
#  'bc8nf',
#  '43xfe',
#  '7xcyd',
#  'ddnpf',
#  '4exnn',
#  '7b4bm',
#  'neecd',
#  'x4f7g',
#  'e76n4',
#  'enn7n',
#  '3x325',
#  '664nf',
#  'cx3wg',
#  '6n6gg',
#  'g55b4',
#  'd3ycn',
#  '7wn74',
#  '245y5',
#  'bdg84',
#  'pym7p',
#  '646x8',
#  'n8pfe',
#  'y53c2',
#  'xxney',
#  '4cn7b',
#  'mmc5n',
#  'xce8d',
#  'e2mg2',
#  'x277e',
#  '8nbew',
#  '55w5c',
#  '24f6w',
#  '3nnpw',
#  'dw8d3',
#  'xcmbp',
#  'cfc56',
#  '85622',
#  '5np4m',
#  'de45x',
#  '6f857',
#  '44xe8',
#  'b43nw',
#  'nb267',
#  'ef4mn',
#  'x7547',
#  '6b46g',
#  'byfgn',
#  'yd755',
#  'nwfde',
#  '7cgym',
#  'yf28d',
#  'cfp86',
#  'ncyx8',
#  '87nym',
#  'cwmny',
#  'pbpgc',
#  'n5wbg',
#  'bcwnn',
#  'p8ngx',
#  'mbp2y',
#  '65ebm',
#  'xnnc3',
#  'nbwnn',
#  'y2xg4',
#  'pwebm',
#  'pcpg6',
#  '44fyb',
#  '6c3p5',
#  'fc2ff',
#  '2nbcx',
#  'cwgyx',
#  'p4pde',
#  '2mg87',
#  'ffd6p',
#  'wce5n',
#  'e43ym',
#  'nn4wx',
#  'g7wxw',
#  'cy3nw',
#  'e46pd',
#  'yxd7m',
#  'mwxwp',
#  'bgd4m',
#  '43mn5',
#  'c55c6',
#  'nbwpn',
#  'w2e87',
#  'c43b4',
#  'gcfgp',
#  '77n6g',
#  'wb3ed',
#  'mggce',
#  'n4b4m',
#  'mye68',
#  'de7f8',
#  '8npd5',
#  '33n73',
#  'm4g8g',
#  '573bn',
#  'ng2gw',
#  'ny3nn',
#  '5x5nx',
#  'f8f8g',
#  '85dxn',
#  'n6f4b',
#  'mp7wp',
#  '8n4n8',
#  'bf52c',
#  '7gce6',
#  'nm46n',
#  'bp6mw',
#  '6c3n6',
#  '6ecbn',
#  'c8fxy',
#  'x7746',
#  '5xwcg',
#  'y866y',
#  '4d22m',
#  '65m85',
#  '73mnx',
#  '4yc85',
#  '678w3',
#  '445cc',
#  'ncfgb',
#  'b2nen',
#  '5dxnm',
#  'gecmf',
#  'x3deb',
#  'f83pn',
#  '2nf26',
#  'm74dm',
#  '6gnm3',
#  'f4fn2',
#  '373gb',
#  '5ep3n',
#  'befbd',
#  'bgem5',
#  '6p7gx',
#  'd7en3',
#  'wmpmp',
#  '2enf4',
#  '2g7nm',
#  'b5fm7',
#  'c5xne',
#  'x775w',
#  'd22y5',
#  'y5w28',
#  'x4pnp',
#  '8cccc',
#  'mnef5',
#  'm22e3',
#  '34b84',
#  'nxxf8',
#  '4m2w5',
#  'nw5b2',
#  'cnex4',
#  '5n245',
#  'fc6xb',
#  'pw5nc',
#  'g888x',
#  '3bnyf',
#  'ee8fg',
#  '6mygb',
#  'cdmn8',
#  'gm7n8',
#  '8wy7d',
#  '7xd5m',
#  'nwncn',
#  'ncw4g',
#  'fcey3',
#  'g7gnf',
#  'en4n4',
#  '2gyb6',
#  '33f7m',
#  '2cgyx',
#  'x7422',
#  'edg3p',
#  '8y6b3',
#  '2b827',
#  'f6ww8',
#  '325fb',
#  'mb4en',
#  'my84e',
#  'nnp4e',
#  '37ep6',
#  '36bc2',
#  'gny6b',
#  'cb8cf',
#  'fbp2c',
#  'c3572',
#  '3bd8f',
#  'cpe63',
#  'n265y',
#  '6ydyp',
#  'cg5dd',
#  'p5g5m',
#  'yeyn4',
#  '56c34',
#  'c3n8x',
#  'fw3b2',
#  'e72cd',
#  'gegw4',
#  'yw667',
#  'p4nm4',
#  'mdyp7',
#  '25w53',
#  '74eyg',
#  'yyg5g',
#  'wfy5m',
#  '8w875',
#  'gymmn',
#  'x458w',
#  'g8gnd',
#  'efg72',
#  '5fyem',
#  '42xpy',
#  'mddgb',
#  'ewnx8',
#  '8684m',
#  'n8ydd',
#  '8w754',
#  '6n443',
#  '6e6pn',
#  'p8c24',
#  '2g783',
#  'mc8w2',
#  '8pfxx',
#  '2fxgd',
#  'ndg2b',
#  '7cdge',
#  'n5cm7',
#  '3wnd3',
#  'ndme7',
#  'n3x4c',
#  'xf4p4',
#  'b5pnn',
#  'nmw46',
#  'b685n',
#  '677g3',
#  '5npdn',
#  'xp24p',
#  'ng756',
#  'fp382',
#  'w4nfx',
#  '66wp5',
#  '7p852',
#  '4dgf7',
#  'pdyc8',
#  'f4wfn',
#  'cpc8c',
#  'd236n',
#  '6f2yc',
#  'wyc25',
#  'c353e',
#  '4n3mn',
#  'm5ym2',
#  'men4f',
#  '6mn8n',
#  'bw6n6',
#  'nngxc',
#  '6cwxe',
#  'm3588',
#  '4b2pw',
#  'p2ym2',
#  '67dey',
#  'x347n',
#  'gbxyy',
#  'd7c5x',
#  '8n5p3',
#  '7gmf3',
#  'ffpxf',
#  'g7fmc',
#  '664dn',
#  'nnn57',
#  'yew6p',
#  'nfndw',
#  'bw44w',
#  'nbf8m',
#  '7f8b3',
#  'gc277',
#  '78eec',
#  'dyp7n',
#  '2nx38',
#  'd3c7y',
#  'gn2xy',
#  '3den6',
#  'dbpcd',
#  'y7x8p',
#  '5g5e5',
#  'gcx6f',
#  '4ycex',
#  '28x47',
#  '7nnnx',
#  'gewfy',
#  '55y2m',
#  '6ng6n',
#  '2wx73',
#  'wg625',
#  'gd8fb',
#  '56ncx',
#  'n3ffn',
#  'gp22x',
#  '58pnp',
#  'n7meb',
#  'fp762',
#  'w4cnn',
#  'efx34',
#  'd8xcn',
#  'yw7ny',
#  'pg2yx',
#  '8n65n',
#  '832f3',
#  'd2nbn',
#  '2bg48',
#  'b4d7c',
#  '46mbm',
#  'gnc3n',
#  'ennmm',
#  '57gnx',
#  'n4xx5',
#  'd22n7',
#  'd3c8y',
#  '253dc',
#  'd6fcn',
#  'cfn53',
#  '7wnpm',
#  'w52fn',
#  'dnmd8',
#  '8y63f',
#  'fxpw3',
#  'cfc2y',
#  '3nw7w',
#  'ccf2w',
#  'gwn53',
#  '32dnn',
#  'nf8b8',
#  'y33nm',
#  'c4bgd',
#  'xnn4d',
#  '6g45w',
#  'cffp4',
#  'mmg2m',
#  'xfg65',
#  'wxcn8',
#  '3fbxd',
#  'dbfen',
#  '22d5n',
#  'e5n66',
#  'pgg3n',
#  '25m6p',
#  'pgmn2',
#  'y5g87',
#  'pcede',
#  'm67b3',
#  'e8dxn',
#  'xc68n',
#  'x5f54',
#  'gy433',
#  'dbny3',
#  'c4527',
#  'wf684',
#  'm6n4x',
#  'dw6mn',
#  'gng6e',
#  'e4gd7',
#  '53mn8',
#  '33ng4',
#  '3bx86',
#  'b4ncn',
#  'b3xpn',
#  'bwmee',
#  'cdcb3',
#  'gy5bf',
#  '387g2',
#  '3bfnd',
#  'mpmy5',
#  '6xpme',
#  'xbcbx',
#  '5f3gf',
#  '76y6f',
#  '8nn73',
#  'cgcgb',
#  '3eny7',
#  '52447',
#  'dxwcw',
#  '5p8fm',
#  'n4wwn',
#  'ycnfc',
#  '368y5',
#  'wm47f',
#  'xe6eb',
#  'pyf65',
#  'fpw76',
#  'cnmnn',
#  'efb3f',
#  'm8m4x',
#  'nnf8b',
#  'ndyfe',
#  'myc3c',
#  'n7dyb',
#  'pg2pm',
#  'n336e',
#  'wdww8',
#  'wxy4n',
#  'yfdn7',
#  'mx8bb',
#  '474ff',
#  '4fp5g',
#  '5n732',
#  'deneb',
#  'pmg55',
#  'mmfm6',
#  'f753f',
#  'n7ff2',
#  'f75cx',
#  'ebcbx',
#  'pxne8',
#  '8db67',
#  'g3dy6',
#  'be3bp',
#  '7dyww',
#  'b6f2p',
#  '3b4we',
#  '8n56m',
#  'x44n4',
#  '2cegf',
#  'gp7c5',
#  'd8dce',
#  '42dw4',
#  'ewcf5',
#  'w8bnx',
#  '6mege',
#  '8gmc4',
#  'e6m6p',
#  'd666m',
#  '62nb3',
#  '5325m',
#  'dnxdp',
#  'fcne6',
#  '8gf7n',
#  'ggd7m',
#  'bw5ym',
#  'pe4xn',
#  'by5y3',
#  'nb45d',
#  '7pcd7',
#  '5yxgp',
#  'dd764',
#  'ccn2x',
#  '3w2bw',
#  'xnfx5',
#  '64m82',
#  '3n3cf',
#  '3ye2e',
#  '3pe4g',
#  '556wd',
#  'ngn26',
#  '5bnd7',
#  '8fexn',
#  'pxdwp',
#  'fg8n4',
#  '44c22',
#  'nfd8g',
#  'w46ep',
#  '6p2ge',
#  'p24gn',
#  'y4ec2',
#  '77wp4',
#  '37d52',
#  'b26nd',
#  'c4mcm',
#  'pgwnp',
#  'gc2wd',
#  'ng6yp',
#  '8bbm4',
#  'xfgxb',
#  '2cg58',
#  'x8xnp',
#  '8c2wy',
#  'ny8np',
#  'enpw2',
#  '6bnnm',
#  'g842c',
#  'g247w',
#  'wddcp',
#  '63pxe',
#  'ep85x',
#  '2wc38',
#  'nxcmn',
#  'm457d',
#  'g78gn',
#  'e7x45',
#  'x2cnn',
#  'mfc35',
#  'm5meg',
#  '3ebpw',
#  'c2g4d',
#  'xdn65',
#  'xnd3y',
#  'ypw3d',
#  'c482b',
#  '675p3',
#  'yx2d4',
#  'neggn',
#  '8ne4g',
#  'fwxdp',
#  'c6we6',
#  '5ywwf',
#  'y7mnm',
#  '4743p',
#  '3p4nn',
#  'mgdwb',
#  'dbex3',
#  'y2436',
#  '5x7x5',
#  'e667x',
#  'wwmn6',
#  'bxxfc',
#  '7fmcy',
#  'x4gg5',
#  'fncnb',
#  '47e4p',
#  '6dmx7',
#  'egxmp',
#  'gm2c2',
#  '8e32m',
#  'fg38b',
#  'y2ye8',
#  'excmn',
#  'wbncw',
#  '7gnge',
#  'ygenn',
#  'yd3m3',
#  '7bwm2',
#  'wnmyn',
#  'nm248',
#  '3g2w6',
#  'nbmx7',
#  '5mcy7',
#  'c6f8g',
#  '6pwcn',
#  '6fn84',
#  'eppg3',
#  '6b4w6',
#  'ng46m',
#  'gw53m',
#  '2ycn8',
#  '3ny45',
#  'pm363',
#  'n2by7',
#  'f22bn',
#  'bnc2f',
#  'ddpyb',
#  'pdw38',
#  'bdbb3',
#  'en32e',
#  '5mgn4',
#  'w7e6m',
#  'xmcym',
#  '57wdp',
#  'n8fp6',
#  'm75bf',
#  'f228n',
#  '8ypdn',
#  '25257',
#  '38n57',
#  'e3ndn',
#  'wecfd',
#  '4c8n8',
#  'bmxpe',
#  '3dgmf',
#  '6825y',
#  'mbf58',
#  '5wddw',
#  'n4cpy',
#  'cen55',
#  '7634y',
#  'n5w5g',
#  'cc845',
#  'w4x2m',
#  'nnfx3',
#  '5xd2e',
#  'w6yne',
#  'x37bf',
#  'y4n6m',
#  'ycmcw',
#  'ddcne',
#  'mmg38',
#  'dmw8n',
#  '7y2x4',
#  'xemyg',
#  'cfw6e',
#  'nfcwy',
#  'gdng3',
#  '4nnf3',
#  'cdf77',
#  '87d4c',
#  'w48cw',
#  '3n7mx',
#  '5mf7c',
#  '8n5pn',
#  'dw3nn',
#  '5pm6b',
#  '33b22',
#  '3ebnn',
#  'd22bd',
#  '2yggg',
#  '58b5m',
#  '4egem',
#  'nbcgb',
#  'y7d75',
#  '32cnn',
#  'e8e5e',
#  'f5cm2',
#  '4dw3w',
#  'xbem6',
#  'pf5ng',
#  'ydd3g',
#  'pm47f',
#  'nxc83',
#  'efgx5',
#  'n6nn2',
#  'd4n82',
#  '2pfpn',
#  'gwnm6',
#  '7w67m',
#  '5gcd3',
#  'gf2g4',
#  '3xng6',
#  'mfb3x',
#  'c7gb3',
#  '378e5',
#  'x6b5m',
#  'eng53',
#  'bn5mw',
#  '2en7g',
#  'w2n7e',
#  'mdxpn',
#  '574d7',
#  '6ge3p',
#  '5mfff',
#  '8gecm',
#  'gpnxn',
#  'pmd3w',
#  '3mxdn',
#  '8b735',
#  'ffnxn',
#  '3ndxd',
#  '8c23f',
#  '6xen4',
#  'gw468',
#  'f364x',
#  'm4fd8',
#  'pnnwy',
#  'fp5wn',
#  'cwdnx',
#  'efe62',
#  'nbp3e',
#  'c2pg6',
#  'px2xp',
#  '573d8',
#  'nybcx',
#  'mcyfx',
#  'nxn4f',
#  'f6ne5',
#  '34pcn',
#  '76353',
#  'myf82',
#  'pwn5e',
#  'c2yn8',
#  'ywn6f',
#  'cnwyc',
#  'dnne7',
#  'gxx2p',
#  '2p2y8',
#  'pgm2e',
#  'fdpgd',
#  'pme86',
#  '56m6y',
#  'mwdf6',
#  'nmy2x',
#  '4nc37',
#  '377xx',
#  '7gp47',
#  'n5n8b',
#  '4fc36',
#  '25p2m',
#  'y32yy',
#  'dfnx4',
#  'feyc8',
#  '5mnpd',
#  'p2dw7',
#  'xxbm5',
#  'xdcn4',
#  'fg7mg',
#  'gfbx6',
#  'edwny',
#  ...]

# %%
targets = [[c for c in x] for x in targets_orig]

# %%
targets
# Out:
# [['n', 'f', '2', 'n', '8'],
#  ['5', '3', '7', 'n', 'f'],
#  ['d', 'e', 'f', 'y', 'x'],
#  ['m', '3', 'b', '5', 'p'],
#  ['d', 'y', 'x', 'n', 'c'],
#  ['f', 'y', 'f', 'b', 'n'],
#  ['3', 'c', 'p', 'w', 'b'],
#  ['n', 'x', 'x', '2', '5'],
#  ['n', '5', 'x', '2', 'n'],
#  ['w', 'y', 'e', '8', '5'],
#  ['2', 'w', '4', 'y', '7'],
#  ['x', 'e', '8', 'x', 'm'],
#  ['6', 'c', 'm', '6', 'm'],
#  ['8', 'n', 'p', 'e', '3'],
#  ['w', 'c', '2', 'b', 'd'],
#  ['6', '8', 'x', '4', '8'],
#  ['p', 'c', 'm', '7', 'f'],
#  ['3', '6', 'n', 'x', '4'],
#  ['f', '2', 'm', '8', 'n'],
#  ['m', 'x', 'n', 'w', '4'],
#  ['f', '8', '5', '8', 'x'],
#  ['8', 'g', '4', 'y', 'p'],
#  ['3', 'n', 'f', 'd', 'n'],
#  ['f', 'p', '3', 'w', 'y'],
#  ['b', 'd', '3', 'b', '7'],
#  ['w', '7', '5', 'w', '8'],
#  ['d', 'p', 'b', 'y', 'd'],
#  ['7', 'm', '8', 'p', 'x'],
#  ['2', '8', '3', '4', '8'],
#  ['8', '6', '5', 'w', 'm'],
#  ['b', '3', '5', 'f', '6'],
#  ['5', 'n', 'm', '6', 'd'],
#  ['7', 'f', 'd', 'e', '7'],
#  ['p', '8', 'w', 'w', 'f'],
#  ['y', 'y', 'n', '5', '7'],
#  ['m', 'g', 'w', '3', 'n'],
#  ['2', 'n', 'p', 'g', '6'],
#  ['4', 'n', '2', 'y', 'g'],
#  ['c', '6', '7', '4', '5'],
#  ['x', '7', '6', 'm', 'n'],
#  ['d', '3', '7', '8', 'n'],
#  ['b', '2', 'g', '8', 'e'],
#  ['b', 'p', 'w', 'd', '7'],
#  ['x', 'x', 'w', '4', '4'],
#  ['n', '7', 'e', 'b', 'x'],
#  ['3', 'y', 'm', '7', 'f'],
#  ['f', '2', 'f', 'g', 'e'],
#  ['n', '6', 'x', 'c', '5'],
#  ['m', 'x', 'y', 'x', 'w'],
#  ['x', 'y', 'n', 'c', 'c'],
#  ['d', 'd', 'm', 'y', 'g'],
#  ['y', 'f', '4', '2', '4'],
#  ['n', 'f', 'b', 'g', '8'],
#  ['7', 'd', 'g', 'c', '2'],
#  ['6', 'd', 'd', '2', 'y'],
#  ['5', 'b', 'g', 'p', '2'],
#  ['5', 'n', 'x', 'n', 'n'],
#  ['n', 'b', 'f', 'x', '5'],
#  ['6', '6', '2', 'b', 'w'],
#  ['c', 'e', 'w', 'n', 'm'],
#  ['m', '2', '5', '7', '6'],
#  ['n', 'c', '4', 'y', 'g'],
#  ['d', 'n', '2', 'y', 'm'],
#  ['e', 'f', '4', 'n', 'p'],
#  ['3', '3', 'p', '4', 'e'],
#  ['x', '6', 'p', 'd', 'b'],
#  ['g', 'n', 'b', 'n', '4'],
#  ['2', '6', '8', 'g', '2'],
#  ['2', '3', 'n', '8', '8'],
#  ['8', '8', 'y', '5', '2'],
#  ['7', '2', '8', 'n', '8'],
#  ['b', '5', 'd', 'n', '4'],
#  ['e', '8', '4', 'n', '2'],
#  ['b', '8', '4', 'x', 'c'],
#  ['e', 'c', 'd', '4', 'w'],
#  ['e', '6', 'b', '7', 'y'],
#  ['w', 'd', '2', 'g', 'b'],
#  ['f', '3', '5', 'x', 'p'],
#  ['m', 'g', '5', 'n', 'n'],
#  ['b', '5', 'n', 'm', 'm'],
#  ['e', 'x', 'y', 'c', 'n'],
#  ['7', 'g', '3', 'n', 'f'],
#  ['8', 'n', '6', '2', 'n'],
#  ['3', 'x', '5', 'f', 'm'],
#  ['e', '7', 'n', 'x', '4'],
#  ['6', 'b', 'x', 'w', 'g'],
#  ['y', '5', 'n', '6', 'd'],
#  ['x', '3', 'f', 'w', 'f'],
#  ['c', '7', 'n', 'n', '8'],
#  ['x', 'f', 'n', '6', 'n'],
#  ['3', 'y', 'g', 'd', 'e'],
#  ['n', '4', '6', '4', 'c'],
#  ['e', '4', '6', 'y', 'w'],
#  ['8', 'b', 'b', 'w', '8'],
#  ['d', 'e', 'e', 'p', '5'],
#  ['4', 'g', 'b', '3', 'f'],
#  ['p', 'y', 'e', 'f', 'b'],
#  ['5', 'n', 'g', 'g', 'g'],
#  ['5', 'n', 'n', 'f', 'f'],
#  ['b', 'n', 'c', '5', 'f'],
#  ['6', 'w', 'b', '7', '6'],
#  ['g', 'f', 'p', '5', '4'],
#  ['m', '3', 'w', 'f', 'w'],
#  ['3', '4', 'f', 'x', 'm'],
#  ['d', 'n', '2', '6', 'n'],
#  ['6', '5', '8', 'x', 'e'],
#  ['6', 'e', '2', 'd', 'g'],
#  ['m', 'n', '5', 'c', '4'],
#  ['7', 'w', 'y', 'p', '4'],
#  ['b', 'n', 'y', '2', '3'],
#  ['m', 'c', '3', '5', 'n'],
#  ['5', 'p', '3', 'm', 'm'],
#  ['5', 'n', '3', 'w', '4'],
#  ['p', '2', 'x', '7', 'x'],
#  ['p', '2', 'm', '6', 'n'],
#  ['n', 'f', '7', 'b', 'n'],
#  ['n', '3', 'b', 'm', '6'],
#  ['x', '3', '8', 'f', 'n'],
#  ['d', 'd', '5', 'w', '5'],
#  ['y', 'p', 'p', '8', 'f'],
#  ['2', '6', '4', 'm', '5'],
#  ['w', 'g', 'n', 'w', 'p'],
#  ['g', 'y', '8', 'x', 'b'],
#  ['f', 'y', '2', 'n', 'd'],
#  ['n', 'n', 'n', '5', 'p'],
#  ['y', 'y', '8', '2', '4'],
#  ['x', 'f', '5', 'g', '7'],
#  ['p', 'n', 'm', 'x', 'f'],
#  ['4', '2', '8', 'b', '6'],
#  ['3', 'n', '2', 'b', '4'],
#  ['3', 'd', '7', 'b', 'd'],
#  ['6', 'f', 'g', '8', 'c'],
#  ['b', 'e', '6', 'n', 'p'],
#  ['x', '3', '6', '2', 'g'],
#  ['2', '3', 'm', 'd', 'g'],
#  ['p', '5', '7', 'f', 'n'],
#  ['b', 'b', 'y', 'm', 'y'],
#  ['6', 'n', '5', 'f', 'd'],
#  ['g', 'c', '8', '3', 'b'],
#  ['p', 'g', '4', 'b', 'f'],
#  ['x', 'w', '4', '6', '5'],
#  ['b', 'w', '5', 'n', 'f'],
#  ['p', 'p', 'x', '7', '7'],
#  ['7', 'e', '2', 'y', '7'],
#  ['4', '7', 'm', '2', 'b'],
#  ['d', '7', 'n', 'n', '3'],
#  ['x', 'y', 'y', 'y', 'w'],
#  ['g', '3', 'e', 'x', '3'],
#  ['n', 'd', 'e', 'c', 'c'],
#  ['d', 'm', 'x', '8', 'p'],
#  ['8', 'x', 'e', 'f', '7'],
#  ['8', 'c', 'm', '4', '6'],
#  ['5', 'n', 'g', '6', 'e'],
#  ['5', '7', 'b', '2', '7'],
#  ['c', '8', 'n', '8', 'c'],
#  ['n', 'y', '3', 'd', 'w'],
#  ['e', 'e', 'n', '2', '3'],
#  ['7', 'y', 'f', '6', '2'],
#  ['8', 'd', '4', 'w', 'm'],
#  ['n', 'd', '5', 'w', 'g'],
#  ['w', 'm', '7', '4', '6'],
#  ['4', 'w', '7', '6', 'g'],
#  ['f', 'y', 'w', 'b', '8'],
#  ['b', 'm', '3', 'p', '8'],
#  ['g', 'f', 'x', 'c', 'c'],
#  ['w', 'n', 'p', 'e', 'c'],
#  ['p', 'p', 'w', 'y', 'd'],
#  ['x', '8', 'e', '8', 'n'],
#  ['4', 'y', 'n', 'f', '3'],
#  ['2', '2', '6', 'm', 'd'],
#  ['c', 'd', '4', 'e', 'g'],
#  ['4', '4', 'y', 'p', 'e'],
#  ['8', 'd', '2', 'n', 'd'],
#  ['n', 'w', 'g', '2', 'm'],
#  ['n', '2', 'g', 'm', 'g'],
#  ['c', 'd', '6', 'p', '4'],
#  ['m', '4', '4', '8', 'b'],
#  ['m', 'm', '3', 'n', 'n'],
#  ['8', '2', '3', 'p', '2'],
#  ['p', 'f', '4', 'n', 'b'],
#  ['p', '5', 'n', 'c', 'e'],
#  ['8', '2', 'f', 'x', '2'],
#  ['2', '3', '5', '6', 'g'],
#  ['y', 'd', 'g', '8', 'n'],
#  ['n', '3', 'm', '6', 'x'],
#  ['f', 'n', 'b', 'f', 'w'],
#  ['3', 'x', 'c', 'g', 'g'],
#  ['4', '8', '8', 'd', 'e'],
#  ['e', 'c', '6', 'p', 'm'],
#  ['b', '5', '5', 'd', '6'],
#  ['x', 'n', 'g', 'x', 'c'],
#  ['d', 'n', '5', 'd', 'f'],
#  ['m', 'd', '3', '4', '4'],
#  ['p', 'd', 'c', 'p', '4'],
#  ['8', 'e', 'g', 'g', 'g'],
#  ['3', '6', 'w', '2', '5'],
#  ['3', 'p', '6', '7', 'n'],
#  ['6', 'b', 'd', 'n', '5'],
#  ['8', 'd', '8', 'e', 'p'],
#  ['c', 'd', 'f', 'e', 'n'],
#  ['m', 'c', 'g', '4', '3'],
#  ['n', 'f', 'c', 'b', '5'],
#  ['g', 'd', '4', 'm', 'f'],
#  ['2', '4', '4', 'e', '2'],
#  ['5', 'n', '7', '2', '8'],
#  ['n', 'e', '3', '2', '5'],
#  ['e', '2', 'd', '6', '6'],
#  ['d', '4', 'p', 'p', 'y'],
#  ['c', '4', 'b', 'n', 'y'],
#  ['6', 'x', 'x', 'd', 'x'],
#  ['6', 'e', 'n', 'd', '3'],
#  ['c', '8', '6', 'm', 'd'],
#  ['w', '2', 'y', 'p', '7'],
#  ['y', 'g', 'f', 'w', 'e'],
#  ['7', 'd', 'x', 'b', 'd'],
#  ['p', 'p', '5', '4', '6'],
#  ['x', 'g', 'c', 'x', 'y'],
#  ['p', 'w', 'm', 'b', 'n'],
#  ['6', 'p', 'f', 'y', '4'],
#  ['g', '2', 'f', 'n', 'w'],
#  ['b', 'g', 'b', '4', '8'],
#  ['x', '7', '4', 'b', '2'],
#  ['d', 'y', '3', 'c', 'x'],
#  ['n', 'f', 'g', '2', '3'],
#  ['d', 'm', 'x', 'p', '8'],
#  ['8', 'n', 'p', '2', '2'],
#  ['n', '3', '7', '3', 'n'],
#  ['f', '5', 'e', '5', 'e'],
#  ['x', '5', 'n', 'y', 'n'],
#  ['m', '2', 'n', 'f', '4'],
#  ['g', 'm', '6', 'n', 'n'],
#  ['y', 'm', 'p', '7', 'g'],
#  ['p', 'm', 'f', '5', 'w'],
#  ['5', 'b', 'g', '8', 'f'],
#  ['7', '4', '8', '5', '3'],
#  ['c', '2', 'f', 'b', '7'],
#  ['w', '6', 'p', 'x', 'y'],
#  ['5', 'b', 'b', '6', '6'],
#  ['7', '5', 'p', 'f', 'w'],
#  ['b', 'p', '2', 'd', '4'],
#  ['5', 'e', 'x', 'p', 'p'],
#  ['m', '8', 'g', 'm', 'x'],
#  ['d', 'c', 'n', 'p', '8'],
#  ['4', 'g', 'y', 'c', 'b'],
#  ['6', 'w', 'g', '4', 'n'],
#  ['f', 'c', 'm', 'e', 'm'],
#  ['n', 'p', 'x', 'b', '7'],
#  ['n', '7', 'e', 'n', 'n'],
#  ['y', '5', 'd', 'p', 'p'],
#  ['c', '7', '5', '3', 'e'],
#  ['6', '8', 'w', 'f', 'd'],
#  ['p', 'x', '8', 'n', '8'],
#  ['6', '4', 'b', '3', 'p'],
#  ['b', '2', '8', 'g', '8'],
#  ['2', 'm', 'p', 'n', 'n'],
#  ['y', 'g', '5', 'b', 'b'],
#  ['8', '4', 'w', '7', 'x'],
#  ['4', '3', 'g', 'e', 'y'],
#  ['d', 'd', 'c', 'd', 'd'],
#  ['c', 'm', '6', 'y', 'b'],
#  ['f', '8', '5', 'y', '3'],
#  ['b', '4', 'y', '5', 'x'],
#  ['2', 'x', '7', 'b', 'm'],
#  ['y', '3', 'c', '5', '8'],
#  ['8', 'n', '2', 'p', 'g'],
#  ['6', 'n', 'g', '6', 'w'],
#  ['n', 'n', 'y', '5', 'e'],
#  ['7', '7', '3', '8', '7'],
#  ['g', 'x', 'x', 'p', 'f'],
#  ['x', 'w', 'x', '7', 'd'],
#  ['d', 'c', 'e', '8', 'y'],
#  ['n', 'y', '5', 'd', 'p'],
#  ['b', 'y', 'c', '8', '2'],
#  ['7', 'm', 'g', 'm', 'f'],
#  ['8', 'g', 'm', 'n', 'x'],
#  ['6', 'm', '5', 'e', 'g'],
#  ['6', '3', '8', '2', '4'],
#  ['8', '8', 'b', 'g', 'x'],
#  ['7', '8', '5', 'n', '4'],
#  ['y', 'b', 'f', 'x', '6'],
#  ['2', 'x', 'c', '2', 'n'],
#  ['e', '2', '5', 'x', 'g'],
#  ['8', 'n', '3', '4', 'n'],
#  ['7', 'b', 'b', '7', 'b'],
#  ['4', 'c', 'f', 'w', '8'],
#  ['y', 'e', 'm', 'y', '4'],
#  ['4', '3', 'p', '5', 'd'],
#  ['m', 'c', 'c', '2', 'x'],
#  ['b', 'n', 'y', '4', 'w'],
#  ['7', 'd', 'w', 'x', '4'],
#  ['x', 'c', 'f', '8', '8'],
#  ['m', 'm', 'y', '5', 'n'],
#  ['7', '2', 'm', '6', 'f'],
#  ['m', 'p', 'x', 'f', 'b'],
#  ['g', 'n', 'f', '8', '5'],
#  ['d', '7', '5', 'b', '5'],
#  ['w', '8', 'f', '3', '6'],
#  ['7', '6', 'n', 'x', 'n'],
#  ['y', '4', 'g', '3', 'b'],
#  ['p', 'p', '8', '7', 'n'],
#  ['6', 'w', 'n', 'y', 'c'],
#  ['6', 'e', '5', '5', '4'],
#  ['2', 'n', '7', '3', 'f'],
#  ['b', 'c', '8', 'n', 'f'],
#  ['4', '3', 'x', 'f', 'e'],
#  ['7', 'x', 'c', 'y', 'd'],
#  ['d', 'd', 'n', 'p', 'f'],
#  ['4', 'e', 'x', 'n', 'n'],
#  ['7', 'b', '4', 'b', 'm'],
#  ['n', 'e', 'e', 'c', 'd'],
#  ['x', '4', 'f', '7', 'g'],
#  ['e', '7', '6', 'n', '4'],
#  ['e', 'n', 'n', '7', 'n'],
#  ['3', 'x', '3', '2', '5'],
#  ['6', '6', '4', 'n', 'f'],
#  ['c', 'x', '3', 'w', 'g'],
#  ['6', 'n', '6', 'g', 'g'],
#  ['g', '5', '5', 'b', '4'],
#  ['d', '3', 'y', 'c', 'n'],
#  ['7', 'w', 'n', '7', '4'],
#  ['2', '4', '5', 'y', '5'],
#  ['b', 'd', 'g', '8', '4'],
#  ['p', 'y', 'm', '7', 'p'],
#  ['6', '4', '6', 'x', '8'],
#  ['n', '8', 'p', 'f', 'e'],
#  ['y', '5', '3', 'c', '2'],
#  ['x', 'x', 'n', 'e', 'y'],
#  ['4', 'c', 'n', '7', 'b'],
#  ['m', 'm', 'c', '5', 'n'],
#  ['x', 'c', 'e', '8', 'd'],
#  ['e', '2', 'm', 'g', '2'],
#  ['x', '2', '7', '7', 'e'],
#  ['8', 'n', 'b', 'e', 'w'],
#  ['5', '5', 'w', '5', 'c'],
#  ['2', '4', 'f', '6', 'w'],
#  ['3', 'n', 'n', 'p', 'w'],
#  ['d', 'w', '8', 'd', '3'],
#  ['x', 'c', 'm', 'b', 'p'],
#  ['c', 'f', 'c', '5', '6'],
#  ['8', '5', '6', '2', '2'],
#  ['5', 'n', 'p', '4', 'm'],
#  ['d', 'e', '4', '5', 'x'],
#  ['6', 'f', '8', '5', '7'],
#  ['4', '4', 'x', 'e', '8'],
#  ['b', '4', '3', 'n', 'w'],
#  ['n', 'b', '2', '6', '7'],
#  ['e', 'f', '4', 'm', 'n'],
#  ['x', '7', '5', '4', '7'],
#  ['6', 'b', '4', '6', 'g'],
#  ['b', 'y', 'f', 'g', 'n'],
#  ['y', 'd', '7', '5', '5'],
#  ['n', 'w', 'f', 'd', 'e'],
#  ['7', 'c', 'g', 'y', 'm'],
#  ['y', 'f', '2', '8', 'd'],
#  ['c', 'f', 'p', '8', '6'],
#  ['n', 'c', 'y', 'x', '8'],
#  ['8', '7', 'n', 'y', 'm'],
#  ['c', 'w', 'm', 'n', 'y'],
#  ['p', 'b', 'p', 'g', 'c'],
#  ['n', '5', 'w', 'b', 'g'],
#  ['b', 'c', 'w', 'n', 'n'],
#  ['p', '8', 'n', 'g', 'x'],
#  ['m', 'b', 'p', '2', 'y'],
#  ['6', '5', 'e', 'b', 'm'],
#  ['x', 'n', 'n', 'c', '3'],
#  ['n', 'b', 'w', 'n', 'n'],
#  ['y', '2', 'x', 'g', '4'],
#  ['p', 'w', 'e', 'b', 'm'],
#  ['p', 'c', 'p', 'g', '6'],
#  ['4', '4', 'f', 'y', 'b'],
#  ['6', 'c', '3', 'p', '5'],
#  ['f', 'c', '2', 'f', 'f'],
#  ['2', 'n', 'b', 'c', 'x'],
#  ['c', 'w', 'g', 'y', 'x'],
#  ['p', '4', 'p', 'd', 'e'],
#  ['2', 'm', 'g', '8', '7'],
#  ['f', 'f', 'd', '6', 'p'],
#  ['w', 'c', 'e', '5', 'n'],
#  ['e', '4', '3', 'y', 'm'],
#  ['n', 'n', '4', 'w', 'x'],
#  ['g', '7', 'w', 'x', 'w'],
#  ['c', 'y', '3', 'n', 'w'],
#  ['e', '4', '6', 'p', 'd'],
#  ['y', 'x', 'd', '7', 'm'],
#  ['m', 'w', 'x', 'w', 'p'],
#  ['b', 'g', 'd', '4', 'm'],
#  ['4', '3', 'm', 'n', '5'],
#  ['c', '5', '5', 'c', '6'],
#  ['n', 'b', 'w', 'p', 'n'],
#  ['w', '2', 'e', '8', '7'],
#  ['c', '4', '3', 'b', '4'],
#  ['g', 'c', 'f', 'g', 'p'],
#  ['7', '7', 'n', '6', 'g'],
#  ['w', 'b', '3', 'e', 'd'],
#  ['m', 'g', 'g', 'c', 'e'],
#  ['n', '4', 'b', '4', 'm'],
#  ['m', 'y', 'e', '6', '8'],
#  ['d', 'e', '7', 'f', '8'],
#  ['8', 'n', 'p', 'd', '5'],
#  ['3', '3', 'n', '7', '3'],
#  ['m', '4', 'g', '8', 'g'],
#  ['5', '7', '3', 'b', 'n'],
#  ['n', 'g', '2', 'g', 'w'],
#  ['n', 'y', '3', 'n', 'n'],
#  ['5', 'x', '5', 'n', 'x'],
#  ['f', '8', 'f', '8', 'g'],
#  ['8', '5', 'd', 'x', 'n'],
#  ['n', '6', 'f', '4', 'b'],
#  ['m', 'p', '7', 'w', 'p'],
#  ['8', 'n', '4', 'n', '8'],
#  ['b', 'f', '5', '2', 'c'],
#  ['7', 'g', 'c', 'e', '6'],
#  ['n', 'm', '4', '6', 'n'],
#  ['b', 'p', '6', 'm', 'w'],
#  ['6', 'c', '3', 'n', '6'],
#  ['6', 'e', 'c', 'b', 'n'],
#  ['c', '8', 'f', 'x', 'y'],
#  ['x', '7', '7', '4', '6'],
#  ['5', 'x', 'w', 'c', 'g'],
#  ['y', '8', '6', '6', 'y'],
#  ['4', 'd', '2', '2', 'm'],
#  ['6', '5', 'm', '8', '5'],
#  ['7', '3', 'm', 'n', 'x'],
#  ['4', 'y', 'c', '8', '5'],
#  ['6', '7', '8', 'w', '3'],
#  ['4', '4', '5', 'c', 'c'],
#  ['n', 'c', 'f', 'g', 'b'],
#  ['b', '2', 'n', 'e', 'n'],
#  ['5', 'd', 'x', 'n', 'm'],
#  ['g', 'e', 'c', 'm', 'f'],
#  ['x', '3', 'd', 'e', 'b'],
#  ['f', '8', '3', 'p', 'n'],
#  ['2', 'n', 'f', '2', '6'],
#  ['m', '7', '4', 'd', 'm'],
#  ['6', 'g', 'n', 'm', '3'],
#  ['f', '4', 'f', 'n', '2'],
#  ['3', '7', '3', 'g', 'b'],
#  ['5', 'e', 'p', '3', 'n'],
#  ['b', 'e', 'f', 'b', 'd'],
#  ['b', 'g', 'e', 'm', '5'],
#  ['6', 'p', '7', 'g', 'x'],
#  ['d', '7', 'e', 'n', '3'],
#  ['w', 'm', 'p', 'm', 'p'],
#  ['2', 'e', 'n', 'f', '4'],
#  ['2', 'g', '7', 'n', 'm'],
#  ['b', '5', 'f', 'm', '7'],
#  ['c', '5', 'x', 'n', 'e'],
#  ['x', '7', '7', '5', 'w'],
#  ['d', '2', '2', 'y', '5'],
#  ['y', '5', 'w', '2', '8'],
#  ['x', '4', 'p', 'n', 'p'],
#  ['8', 'c', 'c', 'c', 'c'],
#  ['m', 'n', 'e', 'f', '5'],
#  ['m', '2', '2', 'e', '3'],
#  ['3', '4', 'b', '8', '4'],
#  ['n', 'x', 'x', 'f', '8'],
#  ['4', 'm', '2', 'w', '5'],
#  ['n', 'w', '5', 'b', '2'],
#  ['c', 'n', 'e', 'x', '4'],
#  ['5', 'n', '2', '4', '5'],
#  ['f', 'c', '6', 'x', 'b'],
#  ['p', 'w', '5', 'n', 'c'],
#  ['g', '8', '8', '8', 'x'],
#  ['3', 'b', 'n', 'y', 'f'],
#  ['e', 'e', '8', 'f', 'g'],
#  ['6', 'm', 'y', 'g', 'b'],
#  ['c', 'd', 'm', 'n', '8'],
#  ['g', 'm', '7', 'n', '8'],
#  ['8', 'w', 'y', '7', 'd'],
#  ['7', 'x', 'd', '5', 'm'],
#  ['n', 'w', 'n', 'c', 'n'],
#  ['n', 'c', 'w', '4', 'g'],
#  ['f', 'c', 'e', 'y', '3'],
#  ['g', '7', 'g', 'n', 'f'],
#  ['e', 'n', '4', 'n', '4'],
#  ['2', 'g', 'y', 'b', '6'],
#  ['3', '3', 'f', '7', 'm'],
#  ['2', 'c', 'g', 'y', 'x'],
#  ['x', '7', '4', '2', '2'],
#  ['e', 'd', 'g', '3', 'p'],
#  ['8', 'y', '6', 'b', '3'],
#  ['2', 'b', '8', '2', '7'],
#  ['f', '6', 'w', 'w', '8'],
#  ['3', '2', '5', 'f', 'b'],
#  ['m', 'b', '4', 'e', 'n'],
#  ['m', 'y', '8', '4', 'e'],
#  ['n', 'n', 'p', '4', 'e'],
#  ['3', '7', 'e', 'p', '6'],
#  ['3', '6', 'b', 'c', '2'],
#  ['g', 'n', 'y', '6', 'b'],
#  ['c', 'b', '8', 'c', 'f'],
#  ['f', 'b', 'p', '2', 'c'],
#  ['c', '3', '5', '7', '2'],
#  ['3', 'b', 'd', '8', 'f'],
#  ['c', 'p', 'e', '6', '3'],
#  ['n', '2', '6', '5', 'y'],
#  ['6', 'y', 'd', 'y', 'p'],
#  ['c', 'g', '5', 'd', 'd'],
#  ['p', '5', 'g', '5', 'm'],
#  ['y', 'e', 'y', 'n', '4'],
#  ['5', '6', 'c', '3', '4'],
#  ['c', '3', 'n', '8', 'x'],
#  ['f', 'w', '3', 'b', '2'],
#  ['e', '7', '2', 'c', 'd'],
#  ['g', 'e', 'g', 'w', '4'],
#  ['y', 'w', '6', '6', '7'],
#  ['p', '4', 'n', 'm', '4'],
#  ['m', 'd', 'y', 'p', '7'],
#  ['2', '5', 'w', '5', '3'],
#  ['7', '4', 'e', 'y', 'g'],
#  ['y', 'y', 'g', '5', 'g'],
#  ['w', 'f', 'y', '5', 'm'],
#  ['8', 'w', '8', '7', '5'],
#  ['g', 'y', 'm', 'm', 'n'],
#  ['x', '4', '5', '8', 'w'],
#  ['g', '8', 'g', 'n', 'd'],
#  ['e', 'f', 'g', '7', '2'],
#  ['5', 'f', 'y', 'e', 'm'],
#  ['4', '2', 'x', 'p', 'y'],
#  ['m', 'd', 'd', 'g', 'b'],
#  ['e', 'w', 'n', 'x', '8'],
#  ['8', '6', '8', '4', 'm'],
#  ['n', '8', 'y', 'd', 'd'],
#  ['8', 'w', '7', '5', '4'],
#  ['6', 'n', '4', '4', '3'],
#  ['6', 'e', '6', 'p', 'n'],
#  ['p', '8', 'c', '2', '4'],
#  ['2', 'g', '7', '8', '3'],
#  ['m', 'c', '8', 'w', '2'],
#  ['8', 'p', 'f', 'x', 'x'],
#  ['2', 'f', 'x', 'g', 'd'],
#  ['n', 'd', 'g', '2', 'b'],
#  ['7', 'c', 'd', 'g', 'e'],
#  ['n', '5', 'c', 'm', '7'],
#  ['3', 'w', 'n', 'd', '3'],
#  ['n', 'd', 'm', 'e', '7'],
#  ['n', '3', 'x', '4', 'c'],
#  ['x', 'f', '4', 'p', '4'],
#  ['b', '5', 'p', 'n', 'n'],
#  ['n', 'm', 'w', '4', '6'],
#  ['b', '6', '8', '5', 'n'],
#  ['6', '7', '7', 'g', '3'],
#  ['5', 'n', 'p', 'd', 'n'],
#  ['x', 'p', '2', '4', 'p'],
#  ['n', 'g', '7', '5', '6'],
#  ['f', 'p', '3', '8', '2'],
#  ['w', '4', 'n', 'f', 'x'],
#  ['6', '6', 'w', 'p', '5'],
#  ['7', 'p', '8', '5', '2'],
#  ['4', 'd', 'g', 'f', '7'],
#  ['p', 'd', 'y', 'c', '8'],
#  ['f', '4', 'w', 'f', 'n'],
#  ['c', 'p', 'c', '8', 'c'],
#  ['d', '2', '3', '6', 'n'],
#  ['6', 'f', '2', 'y', 'c'],
#  ['w', 'y', 'c', '2', '5'],
#  ['c', '3', '5', '3', 'e'],
#  ['4', 'n', '3', 'm', 'n'],
#  ['m', '5', 'y', 'm', '2'],
#  ['m', 'e', 'n', '4', 'f'],
#  ['6', 'm', 'n', '8', 'n'],
#  ['b', 'w', '6', 'n', '6'],
#  ['n', 'n', 'g', 'x', 'c'],
#  ['6', 'c', 'w', 'x', 'e'],
#  ['m', '3', '5', '8', '8'],
#  ['4', 'b', '2', 'p', 'w'],
#  ['p', '2', 'y', 'm', '2'],
#  ['6', '7', 'd', 'e', 'y'],
#  ['x', '3', '4', '7', 'n'],
#  ['g', 'b', 'x', 'y', 'y'],
#  ['d', '7', 'c', '5', 'x'],
#  ['8', 'n', '5', 'p', '3'],
#  ['7', 'g', 'm', 'f', '3'],
#  ['f', 'f', 'p', 'x', 'f'],
#  ['g', '7', 'f', 'm', 'c'],
#  ['6', '6', '4', 'd', 'n'],
#  ['n', 'n', 'n', '5', '7'],
#  ['y', 'e', 'w', '6', 'p'],
#  ['n', 'f', 'n', 'd', 'w'],
#  ['b', 'w', '4', '4', 'w'],
#  ['n', 'b', 'f', '8', 'm'],
#  ['7', 'f', '8', 'b', '3'],
#  ['g', 'c', '2', '7', '7'],
#  ['7', '8', 'e', 'e', 'c'],
#  ['d', 'y', 'p', '7', 'n'],
#  ['2', 'n', 'x', '3', '8'],
#  ['d', '3', 'c', '7', 'y'],
#  ['g', 'n', '2', 'x', 'y'],
#  ['3', 'd', 'e', 'n', '6'],
#  ['d', 'b', 'p', 'c', 'd'],
#  ['y', '7', 'x', '8', 'p'],
#  ['5', 'g', '5', 'e', '5'],
#  ['g', 'c', 'x', '6', 'f'],
#  ['4', 'y', 'c', 'e', 'x'],
#  ['2', '8', 'x', '4', '7'],
#  ['7', 'n', 'n', 'n', 'x'],
#  ['g', 'e', 'w', 'f', 'y'],
#  ['5', '5', 'y', '2', 'm'],
#  ['6', 'n', 'g', '6', 'n'],
#  ['2', 'w', 'x', '7', '3'],
#  ['w', 'g', '6', '2', '5'],
#  ['g', 'd', '8', 'f', 'b'],
#  ['5', '6', 'n', 'c', 'x'],
#  ['n', '3', 'f', 'f', 'n'],
#  ['g', 'p', '2', '2', 'x'],
#  ['5', '8', 'p', 'n', 'p'],
#  ['n', '7', 'm', 'e', 'b'],
#  ['f', 'p', '7', '6', '2'],
#  ['w', '4', 'c', 'n', 'n'],
#  ['e', 'f', 'x', '3', '4'],
#  ['d', '8', 'x', 'c', 'n'],
#  ['y', 'w', '7', 'n', 'y'],
#  ['p', 'g', '2', 'y', 'x'],
#  ['8', 'n', '6', '5', 'n'],
#  ['8', '3', '2', 'f', '3'],
#  ['d', '2', 'n', 'b', 'n'],
#  ['2', 'b', 'g', '4', '8'],
#  ['b', '4', 'd', '7', 'c'],
#  ['4', '6', 'm', 'b', 'm'],
#  ['g', 'n', 'c', '3', 'n'],
#  ['e', 'n', 'n', 'm', 'm'],
#  ['5', '7', 'g', 'n', 'x'],
#  ['n', '4', 'x', 'x', '5'],
#  ['d', '2', '2', 'n', '7'],
#  ['d', '3', 'c', '8', 'y'],
#  ['2', '5', '3', 'd', 'c'],
#  ['d', '6', 'f', 'c', 'n'],
#  ['c', 'f', 'n', '5', '3'],
#  ['7', 'w', 'n', 'p', 'm'],
#  ['w', '5', '2', 'f', 'n'],
#  ['d', 'n', 'm', 'd', '8'],
#  ['8', 'y', '6', '3', 'f'],
#  ['f', 'x', 'p', 'w', '3'],
#  ['c', 'f', 'c', '2', 'y'],
#  ['3', 'n', 'w', '7', 'w'],
#  ['c', 'c', 'f', '2', 'w'],
#  ['g', 'w', 'n', '5', '3'],
#  ['3', '2', 'd', 'n', 'n'],
#  ['n', 'f', '8', 'b', '8'],
#  ['y', '3', '3', 'n', 'm'],
#  ['c', '4', 'b', 'g', 'd'],
#  ['x', 'n', 'n', '4', 'd'],
#  ['6', 'g', '4', '5', 'w'],
#  ['c', 'f', 'f', 'p', '4'],
#  ['m', 'm', 'g', '2', 'm'],
#  ['x', 'f', 'g', '6', '5'],
#  ['w', 'x', 'c', 'n', '8'],
#  ['3', 'f', 'b', 'x', 'd'],
#  ['d', 'b', 'f', 'e', 'n'],
#  ['2', '2', 'd', '5', 'n'],
#  ['e', '5', 'n', '6', '6'],
#  ['p', 'g', 'g', '3', 'n'],
#  ['2', '5', 'm', '6', 'p'],
#  ['p', 'g', 'm', 'n', '2'],
#  ['y', '5', 'g', '8', '7'],
#  ['p', 'c', 'e', 'd', 'e'],
#  ['m', '6', '7', 'b', '3'],
#  ['e', '8', 'd', 'x', 'n'],
#  ['x', 'c', '6', '8', 'n'],
#  ['x', '5', 'f', '5', '4'],
#  ['g', 'y', '4', '3', '3'],
#  ['d', 'b', 'n', 'y', '3'],
#  ['c', '4', '5', '2', '7'],
#  ['w', 'f', '6', '8', '4'],
#  ['m', '6', 'n', '4', 'x'],
#  ['d', 'w', '6', 'm', 'n'],
#  ['g', 'n', 'g', '6', 'e'],
#  ['e', '4', 'g', 'd', '7'],
#  ['5', '3', 'm', 'n', '8'],
#  ['3', '3', 'n', 'g', '4'],
#  ['3', 'b', 'x', '8', '6'],
#  ['b', '4', 'n', 'c', 'n'],
#  ['b', '3', 'x', 'p', 'n'],
#  ['b', 'w', 'm', 'e', 'e'],
#  ['c', 'd', 'c', 'b', '3'],
#  ['g', 'y', '5', 'b', 'f'],
#  ['3', '8', '7', 'g', '2'],
#  ['3', 'b', 'f', 'n', 'd'],
#  ['m', 'p', 'm', 'y', '5'],
#  ['6', 'x', 'p', 'm', 'e'],
#  ['x', 'b', 'c', 'b', 'x'],
#  ['5', 'f', '3', 'g', 'f'],
#  ['7', '6', 'y', '6', 'f'],
#  ['8', 'n', 'n', '7', '3'],
#  ['c', 'g', 'c', 'g', 'b'],
#  ['3', 'e', 'n', 'y', '7'],
#  ['5', '2', '4', '4', '7'],
#  ['d', 'x', 'w', 'c', 'w'],
#  ['5', 'p', '8', 'f', 'm'],
#  ['n', '4', 'w', 'w', 'n'],
#  ['y', 'c', 'n', 'f', 'c'],
#  ['3', '6', '8', 'y', '5'],
#  ['w', 'm', '4', '7', 'f'],
#  ['x', 'e', '6', 'e', 'b'],
#  ['p', 'y', 'f', '6', '5'],
#  ['f', 'p', 'w', '7', '6'],
#  ['c', 'n', 'm', 'n', 'n'],
#  ['e', 'f', 'b', '3', 'f'],
#  ['m', '8', 'm', '4', 'x'],
#  ['n', 'n', 'f', '8', 'b'],
#  ['n', 'd', 'y', 'f', 'e'],
#  ['m', 'y', 'c', '3', 'c'],
#  ['n', '7', 'd', 'y', 'b'],
#  ['p', 'g', '2', 'p', 'm'],
#  ['n', '3', '3', '6', 'e'],
#  ['w', 'd', 'w', 'w', '8'],
#  ['w', 'x', 'y', '4', 'n'],
#  ['y', 'f', 'd', 'n', '7'],
#  ['m', 'x', '8', 'b', 'b'],
#  ['4', '7', '4', 'f', 'f'],
#  ['4', 'f', 'p', '5', 'g'],
#  ['5', 'n', '7', '3', '2'],
#  ['d', 'e', 'n', 'e', 'b'],
#  ['p', 'm', 'g', '5', '5'],
#  ['m', 'm', 'f', 'm', '6'],
#  ['f', '7', '5', '3', 'f'],
#  ['n', '7', 'f', 'f', '2'],
#  ['f', '7', '5', 'c', 'x'],
#  ['e', 'b', 'c', 'b', 'x'],
#  ['p', 'x', 'n', 'e', '8'],
#  ['8', 'd', 'b', '6', '7'],
#  ['g', '3', 'd', 'y', '6'],
#  ['b', 'e', '3', 'b', 'p'],
#  ['7', 'd', 'y', 'w', 'w'],
#  ['b', '6', 'f', '2', 'p'],
#  ['3', 'b', '4', 'w', 'e'],
#  ['8', 'n', '5', '6', 'm'],
#  ['x', '4', '4', 'n', '4'],
#  ['2', 'c', 'e', 'g', 'f'],
#  ['g', 'p', '7', 'c', '5'],
#  ['d', '8', 'd', 'c', 'e'],
#  ['4', '2', 'd', 'w', '4'],
#  ['e', 'w', 'c', 'f', '5'],
#  ['w', '8', 'b', 'n', 'x'],
#  ['6', 'm', 'e', 'g', 'e'],
#  ['8', 'g', 'm', 'c', '4'],
#  ['e', '6', 'm', '6', 'p'],
#  ['d', '6', '6', '6', 'm'],
#  ['6', '2', 'n', 'b', '3'],
#  ['5', '3', '2', '5', 'm'],
#  ['d', 'n', 'x', 'd', 'p'],
#  ['f', 'c', 'n', 'e', '6'],
#  ['8', 'g', 'f', '7', 'n'],
#  ['g', 'g', 'd', '7', 'm'],
#  ['b', 'w', '5', 'y', 'm'],
#  ['p', 'e', '4', 'x', 'n'],
#  ['b', 'y', '5', 'y', '3'],
#  ['n', 'b', '4', '5', 'd'],
#  ['7', 'p', 'c', 'd', '7'],
#  ['5', 'y', 'x', 'g', 'p'],
#  ['d', 'd', '7', '6', '4'],
#  ['c', 'c', 'n', '2', 'x'],
#  ['3', 'w', '2', 'b', 'w'],
#  ['x', 'n', 'f', 'x', '5'],
#  ['6', '4', 'm', '8', '2'],
#  ['3', 'n', '3', 'c', 'f'],
#  ['3', 'y', 'e', '2', 'e'],
#  ['3', 'p', 'e', '4', 'g'],
#  ['5', '5', '6', 'w', 'd'],
#  ['n', 'g', 'n', '2', '6'],
#  ['5', 'b', 'n', 'd', '7'],
#  ['8', 'f', 'e', 'x', 'n'],
#  ['p', 'x', 'd', 'w', 'p'],
#  ['f', 'g', '8', 'n', '4'],
#  ['4', '4', 'c', '2', '2'],
#  ['n', 'f', 'd', '8', 'g'],
#  ['w', '4', '6', 'e', 'p'],
#  ['6', 'p', '2', 'g', 'e'],
#  ['p', '2', '4', 'g', 'n'],
#  ['y', '4', 'e', 'c', '2'],
#  ['7', '7', 'w', 'p', '4'],
#  ['3', '7', 'd', '5', '2'],
#  ['b', '2', '6', 'n', 'd'],
#  ['c', '4', 'm', 'c', 'm'],
#  ['p', 'g', 'w', 'n', 'p'],
#  ['g', 'c', '2', 'w', 'd'],
#  ['n', 'g', '6', 'y', 'p'],
#  ['8', 'b', 'b', 'm', '4'],
#  ['x', 'f', 'g', 'x', 'b'],
#  ['2', 'c', 'g', '5', '8'],
#  ['x', '8', 'x', 'n', 'p'],
#  ['8', 'c', '2', 'w', 'y'],
#  ['n', 'y', '8', 'n', 'p'],
#  ['e', 'n', 'p', 'w', '2'],
#  ['6', 'b', 'n', 'n', 'm'],
#  ['g', '8', '4', '2', 'c'],
#  ['g', '2', '4', '7', 'w'],
#  ['w', 'd', 'd', 'c', 'p'],
#  ['6', '3', 'p', 'x', 'e'],
#  ['e', 'p', '8', '5', 'x'],
#  ['2', 'w', 'c', '3', '8'],
#  ['n', 'x', 'c', 'm', 'n'],
#  ['m', '4', '5', '7', 'd'],
#  ['g', '7', '8', 'g', 'n'],
#  ['e', '7', 'x', '4', '5'],
#  ['x', '2', 'c', 'n', 'n'],
#  ['m', 'f', 'c', '3', '5'],
#  ['m', '5', 'm', 'e', 'g'],
#  ['3', 'e', 'b', 'p', 'w'],
#  ['c', '2', 'g', '4', 'd'],
#  ['x', 'd', 'n', '6', '5'],
#  ['x', 'n', 'd', '3', 'y'],
#  ['y', 'p', 'w', '3', 'd'],
#  ['c', '4', '8', '2', 'b'],
#  ['6', '7', '5', 'p', '3'],
#  ['y', 'x', '2', 'd', '4'],
#  ['n', 'e', 'g', 'g', 'n'],
#  ['8', 'n', 'e', '4', 'g'],
#  ['f', 'w', 'x', 'd', 'p'],
#  ['c', '6', 'w', 'e', '6'],
#  ['5', 'y', 'w', 'w', 'f'],
#  ['y', '7', 'm', 'n', 'm'],
#  ['4', '7', '4', '3', 'p'],
#  ['3', 'p', '4', 'n', 'n'],
#  ['m', 'g', 'd', 'w', 'b'],
#  ['d', 'b', 'e', 'x', '3'],
#  ['y', '2', '4', '3', '6'],
#  ['5', 'x', '7', 'x', '5'],
#  ['e', '6', '6', '7', 'x'],
#  ['w', 'w', 'm', 'n', '6'],
#  ['b', 'x', 'x', 'f', 'c'],
#  ['7', 'f', 'm', 'c', 'y'],
#  ['x', '4', 'g', 'g', '5'],
#  ['f', 'n', 'c', 'n', 'b'],
#  ['4', '7', 'e', '4', 'p'],
#  ['6', 'd', 'm', 'x', '7'],
#  ['e', 'g', 'x', 'm', 'p'],
#  ['g', 'm', '2', 'c', '2'],
#  ['8', 'e', '3', '2', 'm'],
#  ['f', 'g', '3', '8', 'b'],
#  ['y', '2', 'y', 'e', '8'],
#  ['e', 'x', 'c', 'm', 'n'],
#  ['w', 'b', 'n', 'c', 'w'],
#  ['7', 'g', 'n', 'g', 'e'],
#  ['y', 'g', 'e', 'n', 'n'],
#  ['y', 'd', '3', 'm', '3'],
#  ['7', 'b', 'w', 'm', '2'],
#  ['w', 'n', 'm', 'y', 'n'],
#  ['n', 'm', '2', '4', '8'],
#  ['3', 'g', '2', 'w', '6'],
#  ['n', 'b', 'm', 'x', '7'],
#  ['5', 'm', 'c', 'y', '7'],
#  ['c', '6', 'f', '8', 'g'],
#  ['6', 'p', 'w', 'c', 'n'],
#  ['6', 'f', 'n', '8', '4'],
#  ['e', 'p', 'p', 'g', '3'],
#  ['6', 'b', '4', 'w', '6'],
#  ['n', 'g', '4', '6', 'm'],
#  ['g', 'w', '5', '3', 'm'],
#  ['2', 'y', 'c', 'n', '8'],
#  ['3', 'n', 'y', '4', '5'],
#  ['p', 'm', '3', '6', '3'],
#  ['n', '2', 'b', 'y', '7'],
#  ['f', '2', '2', 'b', 'n'],
#  ['b', 'n', 'c', '2', 'f'],
#  ['d', 'd', 'p', 'y', 'b'],
#  ['p', 'd', 'w', '3', '8'],
#  ['b', 'd', 'b', 'b', '3'],
#  ['e', 'n', '3', '2', 'e'],
#  ['5', 'm', 'g', 'n', '4'],
#  ['w', '7', 'e', '6', 'm'],
#  ['x', 'm', 'c', 'y', 'm'],
#  ['5', '7', 'w', 'd', 'p'],
#  ['n', '8', 'f', 'p', '6'],
#  ['m', '7', '5', 'b', 'f'],
#  ['f', '2', '2', '8', 'n'],
#  ['8', 'y', 'p', 'd', 'n'],
#  ['2', '5', '2', '5', '7'],
#  ['3', '8', 'n', '5', '7'],
#  ['e', '3', 'n', 'd', 'n'],
#  ['w', 'e', 'c', 'f', 'd'],
#  ['4', 'c', '8', 'n', '8'],
#  ['b', 'm', 'x', 'p', 'e'],
#  ['3', 'd', 'g', 'm', 'f'],
#  ['6', '8', '2', '5', 'y'],
#  ['m', 'b', 'f', '5', '8'],
#  ['5', 'w', 'd', 'd', 'w'],
#  ['n', '4', 'c', 'p', 'y'],
#  ['c', 'e', 'n', '5', '5'],
#  ['7', '6', '3', '4', 'y'],
#  ['n', '5', 'w', '5', 'g'],
#  ['c', 'c', '8', '4', '5'],
#  ['w', '4', 'x', '2', 'm'],
#  ['n', 'n', 'f', 'x', '3'],
#  ['5', 'x', 'd', '2', 'e'],
#  ['w', '6', 'y', 'n', 'e'],
#  ['x', '3', '7', 'b', 'f'],
#  ['y', '4', 'n', '6', 'm'],
#  ['y', 'c', 'm', 'c', 'w'],
#  ['d', 'd', 'c', 'n', 'e'],
#  ['m', 'm', 'g', '3', '8'],
#  ['d', 'm', 'w', '8', 'n'],
#  ['7', 'y', '2', 'x', '4'],
#  ['x', 'e', 'm', 'y', 'g'],
#  ['c', 'f', 'w', '6', 'e'],
#  ['n', 'f', 'c', 'w', 'y'],
#  ['g', 'd', 'n', 'g', '3'],
#  ['4', 'n', 'n', 'f', '3'],
#  ['c', 'd', 'f', '7', '7'],
#  ['8', '7', 'd', '4', 'c'],
#  ['w', '4', '8', 'c', 'w'],
#  ['3', 'n', '7', 'm', 'x'],
#  ['5', 'm', 'f', '7', 'c'],
#  ['8', 'n', '5', 'p', 'n'],
#  ['d', 'w', '3', 'n', 'n'],
#  ['5', 'p', 'm', '6', 'b'],
#  ['3', '3', 'b', '2', '2'],
#  ['3', 'e', 'b', 'n', 'n'],
#  ['d', '2', '2', 'b', 'd'],
#  ['2', 'y', 'g', 'g', 'g'],
#  ['5', '8', 'b', '5', 'm'],
#  ['4', 'e', 'g', 'e', 'm'],
#  ['n', 'b', 'c', 'g', 'b'],
#  ['y', '7', 'd', '7', '5'],
#  ['3', '2', 'c', 'n', 'n'],
#  ['e', '8', 'e', '5', 'e'],
#  ['f', '5', 'c', 'm', '2'],
#  ['4', 'd', 'w', '3', 'w'],
#  ['x', 'b', 'e', 'm', '6'],
#  ['p', 'f', '5', 'n', 'g'],
#  ['y', 'd', 'd', '3', 'g'],
#  ['p', 'm', '4', '7', 'f'],
#  ['n', 'x', 'c', '8', '3'],
#  ['e', 'f', 'g', 'x', '5'],
#  ['n', '6', 'n', 'n', '2'],
#  ['d', '4', 'n', '8', '2'],
#  ['2', 'p', 'f', 'p', 'n'],
#  ['g', 'w', 'n', 'm', '6'],
#  ['7', 'w', '6', '7', 'm'],
#  ['5', 'g', 'c', 'd', '3'],
#  ['g', 'f', '2', 'g', '4'],
#  ['3', 'x', 'n', 'g', '6'],
#  ['m', 'f', 'b', '3', 'x'],
#  ['c', '7', 'g', 'b', '3'],
#  ['3', '7', '8', 'e', '5'],
#  ['x', '6', 'b', '5', 'm'],
#  ['e', 'n', 'g', '5', '3'],
#  ['b', 'n', '5', 'm', 'w'],
#  ['2', 'e', 'n', '7', 'g'],
#  ['w', '2', 'n', '7', 'e'],
#  ['m', 'd', 'x', 'p', 'n'],
#  ['5', '7', '4', 'd', '7'],
#  ['6', 'g', 'e', '3', 'p'],
#  ['5', 'm', 'f', 'f', 'f'],
#  ['8', 'g', 'e', 'c', 'm'],
#  ['g', 'p', 'n', 'x', 'n'],
#  ['p', 'm', 'd', '3', 'w'],
#  ['3', 'm', 'x', 'd', 'n'],
#  ['8', 'b', '7', '3', '5'],
#  ['f', 'f', 'n', 'x', 'n'],
#  ['3', 'n', 'd', 'x', 'd'],
#  ['8', 'c', '2', '3', 'f'],
#  ['6', 'x', 'e', 'n', '4'],
#  ['g', 'w', '4', '6', '8'],
#  ['f', '3', '6', '4', 'x'],
#  ['m', '4', 'f', 'd', '8'],
#  ['p', 'n', 'n', 'w', 'y'],
#  ['f', 'p', '5', 'w', 'n'],
#  ['c', 'w', 'd', 'n', 'x'],
#  ['e', 'f', 'e', '6', '2'],
#  ['n', 'b', 'p', '3', 'e'],
#  ['c', '2', 'p', 'g', '6'],
#  ['p', 'x', '2', 'x', 'p'],
#  ['5', '7', '3', 'd', '8'],
#  ['n', 'y', 'b', 'c', 'x'],
#  ['m', 'c', 'y', 'f', 'x'],
#  ['n', 'x', 'n', '4', 'f'],
#  ['f', '6', 'n', 'e', '5'],
#  ['3', '4', 'p', 'c', 'n'],
#  ['7', '6', '3', '5', '3'],
#  ['m', 'y', 'f', '8', '2'],
#  ['p', 'w', 'n', '5', 'e'],
#  ['c', '2', 'y', 'n', '8'],
#  ['y', 'w', 'n', '6', 'f'],
#  ['c', 'n', 'w', 'y', 'c'],
#  ['d', 'n', 'n', 'e', '7'],
#  ['g', 'x', 'x', '2', 'p'],
#  ['2', 'p', '2', 'y', '8'],
#  ['p', 'g', 'm', '2', 'e'],
#  ['f', 'd', 'p', 'g', 'd'],
#  ['p', 'm', 'e', '8', '6'],
#  ['5', '6', 'm', '6', 'y'],
#  ['m', 'w', 'd', 'f', '6'],
#  ['n', 'm', 'y', '2', 'x'],
#  ['4', 'n', 'c', '3', '7'],
#  ['3', '7', '7', 'x', 'x'],
#  ['7', 'g', 'p', '4', '7'],
#  ['n', '5', 'n', '8', 'b'],
#  ['4', 'f', 'c', '3', '6'],
#  ['2', '5', 'p', '2', 'm'],
#  ['y', '3', '2', 'y', 'y'],
#  ['d', 'f', 'n', 'x', '4'],
#  ['f', 'e', 'y', 'c', '8'],
#  ['5', 'm', 'n', 'p', 'd'],
#  ['p', '2', 'd', 'w', '7'],
#  ['x', 'x', 'b', 'm', '5'],
#  ['x', 'd', 'c', 'n', '4'],
#  ['f', 'g', '7', 'm', 'g'],
#  ['g', 'f', 'b', 'x', '6'],
#  ['e', 'd', 'w', 'n', 'y'],
#  ...]

# %%
kk  = []
for i in targets_orig:
    for j in i:
        kk.append(j)

# %%
kk
# Out:
# ['n',
#  'f',
#  '2',
#  'n',
#  '8',
#  '5',
#  '3',
#  '7',
#  'n',
#  'f',
#  'd',
#  'e',
#  'f',
#  'y',
#  'x',
#  'm',
#  '3',
#  'b',
#  '5',
#  'p',
#  'd',
#  'y',
#  'x',
#  'n',
#  'c',
#  'f',
#  'y',
#  'f',
#  'b',
#  'n',
#  '3',
#  'c',
#  'p',
#  'w',
#  'b',
#  'n',
#  'x',
#  'x',
#  '2',
#  '5',
#  'n',
#  '5',
#  'x',
#  '2',
#  'n',
#  'w',
#  'y',
#  'e',
#  '8',
#  '5',
#  '2',
#  'w',
#  '4',
#  'y',
#  '7',
#  'x',
#  'e',
#  '8',
#  'x',
#  'm',
#  '6',
#  'c',
#  'm',
#  '6',
#  'm',
#  '8',
#  'n',
#  'p',
#  'e',
#  '3',
#  'w',
#  'c',
#  '2',
#  'b',
#  'd',
#  '6',
#  '8',
#  'x',
#  '4',
#  '8',
#  'p',
#  'c',
#  'm',
#  '7',
#  'f',
#  '3',
#  '6',
#  'n',
#  'x',
#  '4',
#  'f',
#  '2',
#  'm',
#  '8',
#  'n',
#  'm',
#  'x',
#  'n',
#  'w',
#  '4',
#  'f',
#  '8',
#  '5',
#  '8',
#  'x',
#  '8',
#  'g',
#  '4',
#  'y',
#  'p',
#  '3',
#  'n',
#  'f',
#  'd',
#  'n',
#  'f',
#  'p',
#  '3',
#  'w',
#  'y',
#  'b',
#  'd',
#  '3',
#  'b',
#  '7',
#  'w',
#  '7',
#  '5',
#  'w',
#  '8',
#  'd',
#  'p',
#  'b',
#  'y',
#  'd',
#  '7',
#  'm',
#  '8',
#  'p',
#  'x',
#  '2',
#  '8',
#  '3',
#  '4',
#  '8',
#  '8',
#  '6',
#  '5',
#  'w',
#  'm',
#  'b',
#  '3',
#  '5',
#  'f',
#  '6',
#  '5',
#  'n',
#  'm',
#  '6',
#  'd',
#  '7',
#  'f',
#  'd',
#  'e',
#  '7',
#  'p',
#  '8',
#  'w',
#  'w',
#  'f',
#  'y',
#  'y',
#  'n',
#  '5',
#  '7',
#  'm',
#  'g',
#  'w',
#  '3',
#  'n',
#  '2',
#  'n',
#  'p',
#  'g',
#  '6',
#  '4',
#  'n',
#  '2',
#  'y',
#  'g',
#  'c',
#  '6',
#  '7',
#  '4',
#  '5',
#  'x',
#  '7',
#  '6',
#  'm',
#  'n',
#  'd',
#  '3',
#  '7',
#  '8',
#  'n',
#  'b',
#  '2',
#  'g',
#  '8',
#  'e',
#  'b',
#  'p',
#  'w',
#  'd',
#  '7',
#  'x',
#  'x',
#  'w',
#  '4',
#  '4',
#  'n',
#  '7',
#  'e',
#  'b',
#  'x',
#  '3',
#  'y',
#  'm',
#  '7',
#  'f',
#  'f',
#  '2',
#  'f',
#  'g',
#  'e',
#  'n',
#  '6',
#  'x',
#  'c',
#  '5',
#  'm',
#  'x',
#  'y',
#  'x',
#  'w',
#  'x',
#  'y',
#  'n',
#  'c',
#  'c',
#  'd',
#  'd',
#  'm',
#  'y',
#  'g',
#  'y',
#  'f',
#  '4',
#  '2',
#  '4',
#  'n',
#  'f',
#  'b',
#  'g',
#  '8',
#  '7',
#  'd',
#  'g',
#  'c',
#  '2',
#  '6',
#  'd',
#  'd',
#  '2',
#  'y',
#  '5',
#  'b',
#  'g',
#  'p',
#  '2',
#  '5',
#  'n',
#  'x',
#  'n',
#  'n',
#  'n',
#  'b',
#  'f',
#  'x',
#  '5',
#  '6',
#  '6',
#  '2',
#  'b',
#  'w',
#  'c',
#  'e',
#  'w',
#  'n',
#  'm',
#  'm',
#  '2',
#  '5',
#  '7',
#  '6',
#  'n',
#  'c',
#  '4',
#  'y',
#  'g',
#  'd',
#  'n',
#  '2',
#  'y',
#  'm',
#  'e',
#  'f',
#  '4',
#  'n',
#  'p',
#  '3',
#  '3',
#  'p',
#  '4',
#  'e',
#  'x',
#  '6',
#  'p',
#  'd',
#  'b',
#  'g',
#  'n',
#  'b',
#  'n',
#  '4',
#  '2',
#  '6',
#  '8',
#  'g',
#  '2',
#  '2',
#  '3',
#  'n',
#  '8',
#  '8',
#  '8',
#  '8',
#  'y',
#  '5',
#  '2',
#  '7',
#  '2',
#  '8',
#  'n',
#  '8',
#  'b',
#  '5',
#  'd',
#  'n',
#  '4',
#  'e',
#  '8',
#  '4',
#  'n',
#  '2',
#  'b',
#  '8',
#  '4',
#  'x',
#  'c',
#  'e',
#  'c',
#  'd',
#  '4',
#  'w',
#  'e',
#  '6',
#  'b',
#  '7',
#  'y',
#  'w',
#  'd',
#  '2',
#  'g',
#  'b',
#  'f',
#  '3',
#  '5',
#  'x',
#  'p',
#  'm',
#  'g',
#  '5',
#  'n',
#  'n',
#  'b',
#  '5',
#  'n',
#  'm',
#  'm',
#  'e',
#  'x',
#  'y',
#  'c',
#  'n',
#  '7',
#  'g',
#  '3',
#  'n',
#  'f',
#  '8',
#  'n',
#  '6',
#  '2',
#  'n',
#  '3',
#  'x',
#  '5',
#  'f',
#  'm',
#  'e',
#  '7',
#  'n',
#  'x',
#  '4',
#  '6',
#  'b',
#  'x',
#  'w',
#  'g',
#  'y',
#  '5',
#  'n',
#  '6',
#  'd',
#  'x',
#  '3',
#  'f',
#  'w',
#  'f',
#  'c',
#  '7',
#  'n',
#  'n',
#  '8',
#  'x',
#  'f',
#  'n',
#  '6',
#  'n',
#  '3',
#  'y',
#  'g',
#  'd',
#  'e',
#  'n',
#  '4',
#  '6',
#  '4',
#  'c',
#  'e',
#  '4',
#  '6',
#  'y',
#  'w',
#  '8',
#  'b',
#  'b',
#  'w',
#  '8',
#  'd',
#  'e',
#  'e',
#  'p',
#  '5',
#  '4',
#  'g',
#  'b',
#  '3',
#  'f',
#  'p',
#  'y',
#  'e',
#  'f',
#  'b',
#  '5',
#  'n',
#  'g',
#  'g',
#  'g',
#  '5',
#  'n',
#  'n',
#  'f',
#  'f',
#  'b',
#  'n',
#  'c',
#  '5',
#  'f',
#  '6',
#  'w',
#  'b',
#  '7',
#  '6',
#  'g',
#  'f',
#  'p',
#  '5',
#  '4',
#  'm',
#  '3',
#  'w',
#  'f',
#  'w',
#  '3',
#  '4',
#  'f',
#  'x',
#  'm',
#  'd',
#  'n',
#  '2',
#  '6',
#  'n',
#  '6',
#  '5',
#  '8',
#  'x',
#  'e',
#  '6',
#  'e',
#  '2',
#  'd',
#  'g',
#  'm',
#  'n',
#  '5',
#  'c',
#  '4',
#  '7',
#  'w',
#  'y',
#  'p',
#  '4',
#  'b',
#  'n',
#  'y',
#  '2',
#  '3',
#  'm',
#  'c',
#  '3',
#  '5',
#  'n',
#  '5',
#  'p',
#  '3',
#  'm',
#  'm',
#  '5',
#  'n',
#  '3',
#  'w',
#  '4',
#  'p',
#  '2',
#  'x',
#  '7',
#  'x',
#  'p',
#  '2',
#  'm',
#  '6',
#  'n',
#  'n',
#  'f',
#  '7',
#  'b',
#  'n',
#  'n',
#  '3',
#  'b',
#  'm',
#  '6',
#  'x',
#  '3',
#  '8',
#  'f',
#  'n',
#  'd',
#  'd',
#  '5',
#  'w',
#  '5',
#  'y',
#  'p',
#  'p',
#  '8',
#  'f',
#  '2',
#  '6',
#  '4',
#  'm',
#  '5',
#  'w',
#  'g',
#  'n',
#  'w',
#  'p',
#  'g',
#  'y',
#  '8',
#  'x',
#  'b',
#  'f',
#  'y',
#  '2',
#  'n',
#  'd',
#  'n',
#  'n',
#  'n',
#  '5',
#  'p',
#  'y',
#  'y',
#  '8',
#  '2',
#  '4',
#  'x',
#  'f',
#  '5',
#  'g',
#  '7',
#  'p',
#  'n',
#  'm',
#  'x',
#  'f',
#  '4',
#  '2',
#  '8',
#  'b',
#  '6',
#  '3',
#  'n',
#  '2',
#  'b',
#  '4',
#  '3',
#  'd',
#  '7',
#  'b',
#  'd',
#  '6',
#  'f',
#  'g',
#  '8',
#  'c',
#  'b',
#  'e',
#  '6',
#  'n',
#  'p',
#  'x',
#  '3',
#  '6',
#  '2',
#  'g',
#  '2',
#  '3',
#  'm',
#  'd',
#  'g',
#  'p',
#  '5',
#  '7',
#  'f',
#  'n',
#  'b',
#  'b',
#  'y',
#  'm',
#  'y',
#  '6',
#  'n',
#  '5',
#  'f',
#  'd',
#  'g',
#  'c',
#  '8',
#  '3',
#  'b',
#  'p',
#  'g',
#  '4',
#  'b',
#  'f',
#  'x',
#  'w',
#  '4',
#  '6',
#  '5',
#  'b',
#  'w',
#  '5',
#  'n',
#  'f',
#  'p',
#  'p',
#  'x',
#  '7',
#  '7',
#  '7',
#  'e',
#  '2',
#  'y',
#  '7',
#  '4',
#  '7',
#  'm',
#  '2',
#  'b',
#  'd',
#  '7',
#  'n',
#  'n',
#  '3',
#  'x',
#  'y',
#  'y',
#  'y',
#  'w',
#  'g',
#  '3',
#  'e',
#  'x',
#  '3',
#  'n',
#  'd',
#  'e',
#  'c',
#  'c',
#  'd',
#  'm',
#  'x',
#  '8',
#  'p',
#  '8',
#  'x',
#  'e',
#  'f',
#  '7',
#  '8',
#  'c',
#  'm',
#  '4',
#  '6',
#  '5',
#  'n',
#  'g',
#  '6',
#  'e',
#  '5',
#  '7',
#  'b',
#  '2',
#  '7',
#  'c',
#  '8',
#  'n',
#  '8',
#  'c',
#  'n',
#  'y',
#  '3',
#  'd',
#  'w',
#  'e',
#  'e',
#  'n',
#  '2',
#  '3',
#  '7',
#  'y',
#  'f',
#  '6',
#  '2',
#  '8',
#  'd',
#  '4',
#  'w',
#  'm',
#  'n',
#  'd',
#  '5',
#  'w',
#  'g',
#  'w',
#  'm',
#  '7',
#  '4',
#  '6',
#  '4',
#  'w',
#  '7',
#  '6',
#  'g',
#  'f',
#  'y',
#  'w',
#  'b',
#  '8',
#  'b',
#  'm',
#  '3',
#  'p',
#  '8',
#  'g',
#  'f',
#  'x',
#  'c',
#  'c',
#  'w',
#  'n',
#  'p',
#  'e',
#  'c',
#  'p',
#  'p',
#  'w',
#  'y',
#  'd',
#  'x',
#  '8',
#  'e',
#  '8',
#  'n',
#  '4',
#  'y',
#  'n',
#  'f',
#  '3',
#  '2',
#  '2',
#  '6',
#  'm',
#  'd',
#  'c',
#  'd',
#  '4',
#  'e',
#  'g',
#  '4',
#  '4',
#  'y',
#  'p',
#  'e',
#  '8',
#  'd',
#  '2',
#  'n',
#  'd',
#  'n',
#  'w',
#  'g',
#  '2',
#  'm',
#  'n',
#  '2',
#  'g',
#  'm',
#  'g',
#  'c',
#  'd',
#  '6',
#  'p',
#  '4',
#  'm',
#  '4',
#  '4',
#  '8',
#  'b',
#  'm',
#  'm',
#  '3',
#  'n',
#  'n',
#  '8',
#  '2',
#  '3',
#  'p',
#  '2',
#  'p',
#  'f',
#  '4',
#  'n',
#  'b',
#  'p',
#  '5',
#  'n',
#  'c',
#  'e',
#  '8',
#  '2',
#  'f',
#  'x',
#  '2',
#  '2',
#  '3',
#  '5',
#  '6',
#  'g',
#  'y',
#  'd',
#  'g',
#  '8',
#  'n',
#  'n',
#  '3',
#  'm',
#  '6',
#  'x',
#  'f',
#  'n',
#  'b',
#  'f',
#  'w',
#  '3',
#  'x',
#  'c',
#  'g',
#  'g',
#  '4',
#  '8',
#  '8',
#  'd',
#  'e',
#  'e',
#  'c',
#  '6',
#  'p',
#  'm',
#  'b',
#  '5',
#  '5',
#  'd',
#  '6',
#  'x',
#  'n',
#  'g',
#  'x',
#  'c',
#  'd',
#  'n',
#  '5',
#  'd',
#  'f',
#  'm',
#  'd',
#  '3',
#  '4',
#  '4',
#  'p',
#  'd',
#  'c',
#  'p',
#  '4',
#  '8',
#  'e',
#  'g',
#  'g',
#  'g',
#  '3',
#  '6',
#  'w',
#  '2',
#  '5',
#  '3',
#  'p',
#  '6',
#  '7',
#  'n',
#  '6',
#  'b',
#  'd',
#  'n',
#  '5',
#  '8',
#  'd',
#  '8',
#  'e',
#  'p',
#  'c',
#  'd',
#  'f',
#  'e',
#  'n',
#  ...]

# %%
###########   OR ###### 
# try below code.


targets_flat = [c for clist in targets for c in clist]

# %%
targets_flat
# Out:
# ['n',
#  'f',
#  '2',
#  'n',
#  '8',
#  '5',
#  '3',
#  '7',
#  'n',
#  'f',
#  'd',
#  'e',
#  'f',
#  'y',
#  'x',
#  'm',
#  '3',
#  'b',
#  '5',
#  'p',
#  'd',
#  'y',
#  'x',
#  'n',
#  'c',
#  'f',
#  'y',
#  'f',
#  'b',
#  'n',
#  '3',
#  'c',
#  'p',
#  'w',
#  'b',
#  'n',
#  'x',
#  'x',
#  '2',
#  '5',
#  'n',
#  '5',
#  'x',
#  '2',
#  'n',
#  'w',
#  'y',
#  'e',
#  '8',
#  '5',
#  '2',
#  'w',
#  '4',
#  'y',
#  '7',
#  'x',
#  'e',
#  '8',
#  'x',
#  'm',
#  '6',
#  'c',
#  'm',
#  '6',
#  'm',
#  '8',
#  'n',
#  'p',
#  'e',
#  '3',
#  'w',
#  'c',
#  '2',
#  'b',
#  'd',
#  '6',
#  '8',
#  'x',
#  '4',
#  '8',
#  'p',
#  'c',
#  'm',
#  '7',
#  'f',
#  '3',
#  '6',
#  'n',
#  'x',
#  '4',
#  'f',
#  '2',
#  'm',
#  '8',
#  'n',
#  'm',
#  'x',
#  'n',
#  'w',
#  '4',
#  'f',
#  '8',
#  '5',
#  '8',
#  'x',
#  '8',
#  'g',
#  '4',
#  'y',
#  'p',
#  '3',
#  'n',
#  'f',
#  'd',
#  'n',
#  'f',
#  'p',
#  '3',
#  'w',
#  'y',
#  'b',
#  'd',
#  '3',
#  'b',
#  '7',
#  'w',
#  '7',
#  '5',
#  'w',
#  '8',
#  'd',
#  'p',
#  'b',
#  'y',
#  'd',
#  '7',
#  'm',
#  '8',
#  'p',
#  'x',
#  '2',
#  '8',
#  '3',
#  '4',
#  '8',
#  '8',
#  '6',
#  '5',
#  'w',
#  'm',
#  'b',
#  '3',
#  '5',
#  'f',
#  '6',
#  '5',
#  'n',
#  'm',
#  '6',
#  'd',
#  '7',
#  'f',
#  'd',
#  'e',
#  '7',
#  'p',
#  '8',
#  'w',
#  'w',
#  'f',
#  'y',
#  'y',
#  'n',
#  '5',
#  '7',
#  'm',
#  'g',
#  'w',
#  '3',
#  'n',
#  '2',
#  'n',
#  'p',
#  'g',
#  '6',
#  '4',
#  'n',
#  '2',
#  'y',
#  'g',
#  'c',
#  '6',
#  '7',
#  '4',
#  '5',
#  'x',
#  '7',
#  '6',
#  'm',
#  'n',
#  'd',
#  '3',
#  '7',
#  '8',
#  'n',
#  'b',
#  '2',
#  'g',
#  '8',
#  'e',
#  'b',
#  'p',
#  'w',
#  'd',
#  '7',
#  'x',
#  'x',
#  'w',
#  '4',
#  '4',
#  'n',
#  '7',
#  'e',
#  'b',
#  'x',
#  '3',
#  'y',
#  'm',
#  '7',
#  'f',
#  'f',
#  '2',
#  'f',
#  'g',
#  'e',
#  'n',
#  '6',
#  'x',
#  'c',
#  '5',
#  'm',
#  'x',
#  'y',
#  'x',
#  'w',
#  'x',
#  'y',
#  'n',
#  'c',
#  'c',
#  'd',
#  'd',
#  'm',
#  'y',
#  'g',
#  'y',
#  'f',
#  '4',
#  '2',
#  '4',
#  'n',
#  'f',
#  'b',
#  'g',
#  '8',
#  '7',
#  'd',
#  'g',
#  'c',
#  '2',
#  '6',
#  'd',
#  'd',
#  '2',
#  'y',
#  '5',
#  'b',
#  'g',
#  'p',
#  '2',
#  '5',
#  'n',
#  'x',
#  'n',
#  'n',
#  'n',
#  'b',
#  'f',
#  'x',
#  '5',
#  '6',
#  '6',
#  '2',
#  'b',
#  'w',
#  'c',
#  'e',
#  'w',
#  'n',
#  'm',
#  'm',
#  '2',
#  '5',
#  '7',
#  '6',
#  'n',
#  'c',
#  '4',
#  'y',
#  'g',
#  'd',
#  'n',
#  '2',
#  'y',
#  'm',
#  'e',
#  'f',
#  '4',
#  'n',
#  'p',
#  '3',
#  '3',
#  'p',
#  '4',
#  'e',
#  'x',
#  '6',
#  'p',
#  'd',
#  'b',
#  'g',
#  'n',
#  'b',
#  'n',
#  '4',
#  '2',
#  '6',
#  '8',
#  'g',
#  '2',
#  '2',
#  '3',
#  'n',
#  '8',
#  '8',
#  '8',
#  '8',
#  'y',
#  '5',
#  '2',
#  '7',
#  '2',
#  '8',
#  'n',
#  '8',
#  'b',
#  '5',
#  'd',
#  'n',
#  '4',
#  'e',
#  '8',
#  '4',
#  'n',
#  '2',
#  'b',
#  '8',
#  '4',
#  'x',
#  'c',
#  'e',
#  'c',
#  'd',
#  '4',
#  'w',
#  'e',
#  '6',
#  'b',
#  '7',
#  'y',
#  'w',
#  'd',
#  '2',
#  'g',
#  'b',
#  'f',
#  '3',
#  '5',
#  'x',
#  'p',
#  'm',
#  'g',
#  '5',
#  'n',
#  'n',
#  'b',
#  '5',
#  'n',
#  'm',
#  'm',
#  'e',
#  'x',
#  'y',
#  'c',
#  'n',
#  '7',
#  'g',
#  '3',
#  'n',
#  'f',
#  '8',
#  'n',
#  '6',
#  '2',
#  'n',
#  '3',
#  'x',
#  '5',
#  'f',
#  'm',
#  'e',
#  '7',
#  'n',
#  'x',
#  '4',
#  '6',
#  'b',
#  'x',
#  'w',
#  'g',
#  'y',
#  '5',
#  'n',
#  '6',
#  'd',
#  'x',
#  '3',
#  'f',
#  'w',
#  'f',
#  'c',
#  '7',
#  'n',
#  'n',
#  '8',
#  'x',
#  'f',
#  'n',
#  '6',
#  'n',
#  '3',
#  'y',
#  'g',
#  'd',
#  'e',
#  'n',
#  '4',
#  '6',
#  '4',
#  'c',
#  'e',
#  '4',
#  '6',
#  'y',
#  'w',
#  '8',
#  'b',
#  'b',
#  'w',
#  '8',
#  'd',
#  'e',
#  'e',
#  'p',
#  '5',
#  '4',
#  'g',
#  'b',
#  '3',
#  'f',
#  'p',
#  'y',
#  'e',
#  'f',
#  'b',
#  '5',
#  'n',
#  'g',
#  'g',
#  'g',
#  '5',
#  'n',
#  'n',
#  'f',
#  'f',
#  'b',
#  'n',
#  'c',
#  '5',
#  'f',
#  '6',
#  'w',
#  'b',
#  '7',
#  '6',
#  'g',
#  'f',
#  'p',
#  '5',
#  '4',
#  'm',
#  '3',
#  'w',
#  'f',
#  'w',
#  '3',
#  '4',
#  'f',
#  'x',
#  'm',
#  'd',
#  'n',
#  '2',
#  '6',
#  'n',
#  '6',
#  '5',
#  '8',
#  'x',
#  'e',
#  '6',
#  'e',
#  '2',
#  'd',
#  'g',
#  'm',
#  'n',
#  '5',
#  'c',
#  '4',
#  '7',
#  'w',
#  'y',
#  'p',
#  '4',
#  'b',
#  'n',
#  'y',
#  '2',
#  '3',
#  'm',
#  'c',
#  '3',
#  '5',
#  'n',
#  '5',
#  'p',
#  '3',
#  'm',
#  'm',
#  '5',
#  'n',
#  '3',
#  'w',
#  '4',
#  'p',
#  '2',
#  'x',
#  '7',
#  'x',
#  'p',
#  '2',
#  'm',
#  '6',
#  'n',
#  'n',
#  'f',
#  '7',
#  'b',
#  'n',
#  'n',
#  '3',
#  'b',
#  'm',
#  '6',
#  'x',
#  '3',
#  '8',
#  'f',
#  'n',
#  'd',
#  'd',
#  '5',
#  'w',
#  '5',
#  'y',
#  'p',
#  'p',
#  '8',
#  'f',
#  '2',
#  '6',
#  '4',
#  'm',
#  '5',
#  'w',
#  'g',
#  'n',
#  'w',
#  'p',
#  'g',
#  'y',
#  '8',
#  'x',
#  'b',
#  'f',
#  'y',
#  '2',
#  'n',
#  'd',
#  'n',
#  'n',
#  'n',
#  '5',
#  'p',
#  'y',
#  'y',
#  '8',
#  '2',
#  '4',
#  'x',
#  'f',
#  '5',
#  'g',
#  '7',
#  'p',
#  'n',
#  'm',
#  'x',
#  'f',
#  '4',
#  '2',
#  '8',
#  'b',
#  '6',
#  '3',
#  'n',
#  '2',
#  'b',
#  '4',
#  '3',
#  'd',
#  '7',
#  'b',
#  'd',
#  '6',
#  'f',
#  'g',
#  '8',
#  'c',
#  'b',
#  'e',
#  '6',
#  'n',
#  'p',
#  'x',
#  '3',
#  '6',
#  '2',
#  'g',
#  '2',
#  '3',
#  'm',
#  'd',
#  'g',
#  'p',
#  '5',
#  '7',
#  'f',
#  'n',
#  'b',
#  'b',
#  'y',
#  'm',
#  'y',
#  '6',
#  'n',
#  '5',
#  'f',
#  'd',
#  'g',
#  'c',
#  '8',
#  '3',
#  'b',
#  'p',
#  'g',
#  '4',
#  'b',
#  'f',
#  'x',
#  'w',
#  '4',
#  '6',
#  '5',
#  'b',
#  'w',
#  '5',
#  'n',
#  'f',
#  'p',
#  'p',
#  'x',
#  '7',
#  '7',
#  '7',
#  'e',
#  '2',
#  'y',
#  '7',
#  '4',
#  '7',
#  'm',
#  '2',
#  'b',
#  'd',
#  '7',
#  'n',
#  'n',
#  '3',
#  'x',
#  'y',
#  'y',
#  'y',
#  'w',
#  'g',
#  '3',
#  'e',
#  'x',
#  '3',
#  'n',
#  'd',
#  'e',
#  'c',
#  'c',
#  'd',
#  'm',
#  'x',
#  '8',
#  'p',
#  '8',
#  'x',
#  'e',
#  'f',
#  '7',
#  '8',
#  'c',
#  'm',
#  '4',
#  '6',
#  '5',
#  'n',
#  'g',
#  '6',
#  'e',
#  '5',
#  '7',
#  'b',
#  '2',
#  '7',
#  'c',
#  '8',
#  'n',
#  '8',
#  'c',
#  'n',
#  'y',
#  '3',
#  'd',
#  'w',
#  'e',
#  'e',
#  'n',
#  '2',
#  '3',
#  '7',
#  'y',
#  'f',
#  '6',
#  '2',
#  '8',
#  'd',
#  '4',
#  'w',
#  'm',
#  'n',
#  'd',
#  '5',
#  'w',
#  'g',
#  'w',
#  'm',
#  '7',
#  '4',
#  '6',
#  '4',
#  'w',
#  '7',
#  '6',
#  'g',
#  'f',
#  'y',
#  'w',
#  'b',
#  '8',
#  'b',
#  'm',
#  '3',
#  'p',
#  '8',
#  'g',
#  'f',
#  'x',
#  'c',
#  'c',
#  'w',
#  'n',
#  'p',
#  'e',
#  'c',
#  'p',
#  'p',
#  'w',
#  'y',
#  'd',
#  'x',
#  '8',
#  'e',
#  '8',
#  'n',
#  '4',
#  'y',
#  'n',
#  'f',
#  '3',
#  '2',
#  '2',
#  '6',
#  'm',
#  'd',
#  'c',
#  'd',
#  '4',
#  'e',
#  'g',
#  '4',
#  '4',
#  'y',
#  'p',
#  'e',
#  '8',
#  'd',
#  '2',
#  'n',
#  'd',
#  'n',
#  'w',
#  'g',
#  '2',
#  'm',
#  'n',
#  '2',
#  'g',
#  'm',
#  'g',
#  'c',
#  'd',
#  '6',
#  'p',
#  '4',
#  'm',
#  '4',
#  '4',
#  '8',
#  'b',
#  'm',
#  'm',
#  '3',
#  'n',
#  'n',
#  '8',
#  '2',
#  '3',
#  'p',
#  '2',
#  'p',
#  'f',
#  '4',
#  'n',
#  'b',
#  'p',
#  '5',
#  'n',
#  'c',
#  'e',
#  '8',
#  '2',
#  'f',
#  'x',
#  '2',
#  '2',
#  '3',
#  '5',
#  '6',
#  'g',
#  'y',
#  'd',
#  'g',
#  '8',
#  'n',
#  'n',
#  '3',
#  'm',
#  '6',
#  'x',
#  'f',
#  'n',
#  'b',
#  'f',
#  'w',
#  '3',
#  'x',
#  'c',
#  'g',
#  'g',
#  '4',
#  '8',
#  '8',
#  'd',
#  'e',
#  'e',
#  'c',
#  '6',
#  'p',
#  'm',
#  'b',
#  '5',
#  '5',
#  'd',
#  '6',
#  'x',
#  'n',
#  'g',
#  'x',
#  'c',
#  'd',
#  'n',
#  '5',
#  'd',
#  'f',
#  'm',
#  'd',
#  '3',
#  '4',
#  '4',
#  'p',
#  'd',
#  'c',
#  'p',
#  '4',
#  '8',
#  'e',
#  'g',
#  'g',
#  'g',
#  '3',
#  '6',
#  'w',
#  '2',
#  '5',
#  '3',
#  'p',
#  '6',
#  '7',
#  'n',
#  '6',
#  'b',
#  'd',
#  'n',
#  '5',
#  '8',
#  'd',
#  '8',
#  'e',
#  'p',
#  'c',
#  'd',
#  'f',
#  'e',
#  'n',
#  ...]

# %%
from sklearn import preprocessing 

lbl_enc = preprocessing.LabelEncoder()  
# here we r encoding the labels. 
lbl_enc.fit(targets_flat)
# Out:
# LabelEncoder()

# %%
targets_enc = [lbl_enc.transform(x) for x in targets]
# targets_enc = np.array(targets_enc) + 1

# %%
targets_enc
# Out:
# [array([14, 11,  0, 14,  6]),
#  array([ 3,  1,  5, 14, 11]),
#  array([ 9, 10, 11, 18, 17]),
#  array([13,  1,  7,  3, 15]),
#  array([ 9, 18, 17, 14,  8]),
#  array([11, 18, 11,  7, 14]),
#  array([ 1,  8, 15, 16,  7]),
#  array([14, 17, 17,  0,  3]),
#  array([14,  3, 17,  0, 14]),
#  array([16, 18, 10,  6,  3]),
#  array([ 0, 16,  2, 18,  5]),
#  array([17, 10,  6, 17, 13]),
#  array([ 4,  8, 13,  4, 13]),
#  array([ 6, 14, 15, 10,  1]),
#  array([16,  8,  0,  7,  9]),
#  array([ 4,  6, 17,  2,  6]),
#  array([15,  8, 13,  5, 11]),
#  array([ 1,  4, 14, 17,  2]),
#  array([11,  0, 13,  6, 14]),
#  array([13, 17, 14, 16,  2]),
#  array([11,  6,  3,  6, 17]),
#  array([ 6, 12,  2, 18, 15]),
#  array([ 1, 14, 11,  9, 14]),
#  array([11, 15,  1, 16, 18]),
#  array([7, 9, 1, 7, 5]),
#  array([16,  5,  3, 16,  6]),
#  array([ 9, 15,  7, 18,  9]),
#  array([ 5, 13,  6, 15, 17]),
#  array([0, 6, 1, 2, 6]),
#  array([ 6,  4,  3, 16, 13]),
#  array([ 7,  1,  3, 11,  4]),
#  array([ 3, 14, 13,  4,  9]),
#  array([ 5, 11,  9, 10,  5]),
#  array([15,  6, 16, 16, 11]),
#  array([18, 18, 14,  3,  5]),
#  array([13, 12, 16,  1, 14]),
#  array([ 0, 14, 15, 12,  4]),
#  array([ 2, 14,  0, 18, 12]),
#  array([8, 4, 5, 2, 3]),
#  array([17,  5,  4, 13, 14]),
#  array([ 9,  1,  5,  6, 14]),
#  array([ 7,  0, 12,  6, 10]),
#  array([ 7, 15, 16,  9,  5]),
#  array([17, 17, 16,  2,  2]),
#  array([14,  5, 10,  7, 17]),
#  array([ 1, 18, 13,  5, 11]),
#  array([11,  0, 11, 12, 10]),
#  array([14,  4, 17,  8,  3]),
#  array([13, 17, 18, 17, 16]),
#  array([17, 18, 14,  8,  8]),
#  array([ 9,  9, 13, 18, 12]),
#  array([18, 11,  2,  0,  2]),
#  array([14, 11,  7, 12,  6]),
#  array([ 5,  9, 12,  8,  0]),
#  array([ 4,  9,  9,  0, 18]),
#  array([ 3,  7, 12, 15,  0]),
#  array([ 3, 14, 17, 14, 14]),
#  array([14,  7, 11, 17,  3]),
#  array([ 4,  4,  0,  7, 16]),
#  array([ 8, 10, 16, 14, 13]),
#  array([13,  0,  3,  5,  4]),
#  array([14,  8,  2, 18, 12]),
#  array([ 9, 14,  0, 18, 13]),
#  array([10, 11,  2, 14, 15]),
#  array([ 1,  1, 15,  2, 10]),
#  array([17,  4, 15,  9,  7]),
#  array([12, 14,  7, 14,  2]),
#  array([ 0,  4,  6, 12,  0]),
#  array([ 0,  1, 14,  6,  6]),
#  array([ 6,  6, 18,  3,  0]),
#  array([ 5,  0,  6, 14,  6]),
#  array([ 7,  3,  9, 14,  2]),
#  array([10,  6,  2, 14,  0]),
#  array([ 7,  6,  2, 17,  8]),
#  array([10,  8,  9,  2, 16]),
#  array([10,  4,  7,  5, 18]),
#  array([16,  9,  0, 12,  7]),
#  array([11,  1,  3, 17, 15]),
#  array([13, 12,  3, 14, 14]),
#  array([ 7,  3, 14, 13, 13]),
#  array([10, 17, 18,  8, 14]),
#  array([ 5, 12,  1, 14, 11]),
#  array([ 6, 14,  4,  0, 14]),
#  array([ 1, 17,  3, 11, 13]),
#  array([10,  5, 14, 17,  2]),
#  array([ 4,  7, 17, 16, 12]),
#  array([18,  3, 14,  4,  9]),
#  array([17,  1, 11, 16, 11]),
#  array([ 8,  5, 14, 14,  6]),
#  array([17, 11, 14,  4, 14]),
#  array([ 1, 18, 12,  9, 10]),
#  array([14,  2,  4,  2,  8]),
#  array([10,  2,  4, 18, 16]),
#  array([ 6,  7,  7, 16,  6]),
#  array([ 9, 10, 10, 15,  3]),
#  array([ 2, 12,  7,  1, 11]),
#  array([15, 18, 10, 11,  7]),
#  array([ 3, 14, 12, 12, 12]),
#  array([ 3, 14, 14, 11, 11]),
#  array([ 7, 14,  8,  3, 11]),
#  array([ 4, 16,  7,  5,  4]),
#  array([12, 11, 15,  3,  2]),
#  array([13,  1, 16, 11, 16]),
#  array([ 1,  2, 11, 17, 13]),
#  array([ 9, 14,  0,  4, 14]),
#  array([ 4,  3,  6, 17, 10]),
#  array([ 4, 10,  0,  9, 12]),
#  array([13, 14,  3,  8,  2]),
#  array([ 5, 16, 18, 15,  2]),
#  array([ 7, 14, 18,  0,  1]),
#  array([13,  8,  1,  3, 14]),
#  array([ 3, 15,  1, 13, 13]),
#  array([ 3, 14,  1, 16,  2]),
#  array([15,  0, 17,  5, 17]),
#  array([15,  0, 13,  4, 14]),
#  array([14, 11,  5,  7, 14]),
#  array([14,  1,  7, 13,  4]),
#  array([17,  1,  6, 11, 14]),
#  array([ 9,  9,  3, 16,  3]),
#  array([18, 15, 15,  6, 11]),
#  array([ 0,  4,  2, 13,  3]),
#  array([16, 12, 14, 16, 15]),
#  array([12, 18,  6, 17,  7]),
#  array([11, 18,  0, 14,  9]),
#  array([14, 14, 14,  3, 15]),
#  array([18, 18,  6,  0,  2]),
#  array([17, 11,  3, 12,  5]),
#  array([15, 14, 13, 17, 11]),
#  array([2, 0, 6, 7, 4]),
#  array([ 1, 14,  0,  7,  2]),
#  array([1, 9, 5, 7, 9]),
#  array([ 4, 11, 12,  6,  8]),
#  array([ 7, 10,  4, 14, 15]),
#  array([17,  1,  4,  0, 12]),
#  array([ 0,  1, 13,  9, 12]),
#  array([15,  3,  5, 11, 14]),
#  array([ 7,  7, 18, 13, 18]),
#  array([ 4, 14,  3, 11,  9]),
#  array([12,  8,  6,  1,  7]),
#  array([15, 12,  2,  7, 11]),
#  array([17, 16,  2,  4,  3]),
#  array([ 7, 16,  3, 14, 11]),
#  array([15, 15, 17,  5,  5]),
#  array([ 5, 10,  0, 18,  5]),
#  array([ 2,  5, 13,  0,  7]),
#  array([ 9,  5, 14, 14,  1]),
#  array([17, 18, 18, 18, 16]),
#  array([12,  1, 10, 17,  1]),
#  array([14,  9, 10,  8,  8]),
#  array([ 9, 13, 17,  6, 15]),
#  array([ 6, 17, 10, 11,  5]),
#  array([ 6,  8, 13,  2,  4]),
#  array([ 3, 14, 12,  4, 10]),
#  array([3, 5, 7, 0, 5]),
#  array([ 8,  6, 14,  6,  8]),
#  array([14, 18,  1,  9, 16]),
#  array([10, 10, 14,  0,  1]),
#  array([ 5, 18, 11,  4,  0]),
#  array([ 6,  9,  2, 16, 13]),
#  array([14,  9,  3, 16, 12]),
#  array([16, 13,  5,  2,  4]),
#  array([ 2, 16,  5,  4, 12]),
#  array([11, 18, 16,  7,  6]),
#  array([ 7, 13,  1, 15,  6]),
#  array([12, 11, 17,  8,  8]),
#  array([16, 14, 15, 10,  8]),
#  array([15, 15, 16, 18,  9]),
#  array([17,  6, 10,  6, 14]),
#  array([ 2, 18, 14, 11,  1]),
#  array([ 0,  0,  4, 13,  9]),
#  array([ 8,  9,  2, 10, 12]),
#  array([ 2,  2, 18, 15, 10]),
#  array([ 6,  9,  0, 14,  9]),
#  array([14, 16, 12,  0, 13]),
#  array([14,  0, 12, 13, 12]),
#  array([ 8,  9,  4, 15,  2]),
#  array([13,  2,  2,  6,  7]),
#  array([13, 13,  1, 14, 14]),
#  array([ 6,  0,  1, 15,  0]),
#  array([15, 11,  2, 14,  7]),
#  array([15,  3, 14,  8, 10]),
#  array([ 6,  0, 11, 17,  0]),
#  array([ 0,  1,  3,  4, 12]),
#  array([18,  9, 12,  6, 14]),
#  array([14,  1, 13,  4, 17]),
#  array([11, 14,  7, 11, 16]),
#  array([ 1, 17,  8, 12, 12]),
#  array([ 2,  6,  6,  9, 10]),
#  array([10,  8,  4, 15, 13]),
#  array([7, 3, 3, 9, 4]),
#  array([17, 14, 12, 17,  8]),
#  array([ 9, 14,  3,  9, 11]),
#  array([13,  9,  1,  2,  2]),
#  array([15,  9,  8, 15,  2]),
#  array([ 6, 10, 12, 12, 12]),
#  array([ 1,  4, 16,  0,  3]),
#  array([ 1, 15,  4,  5, 14]),
#  array([ 4,  7,  9, 14,  3]),
#  array([ 6,  9,  6, 10, 15]),
#  array([ 8,  9, 11, 10, 14]),
#  array([13,  8, 12,  2,  1]),
#  array([14, 11,  8,  7,  3]),
#  array([12,  9,  2, 13, 11]),
#  array([ 0,  2,  2, 10,  0]),
#  array([ 3, 14,  5,  0,  6]),
#  array([14, 10,  1,  0,  3]),
#  array([10,  0,  9,  4,  4]),
#  array([ 9,  2, 15, 15, 18]),
#  array([ 8,  2,  7, 14, 18]),
#  array([ 4, 17, 17,  9, 17]),
#  array([ 4, 10, 14,  9,  1]),
#  array([ 8,  6,  4, 13,  9]),
#  array([16,  0, 18, 15,  5]),
#  array([18, 12, 11, 16, 10]),
#  array([ 5,  9, 17,  7,  9]),
#  array([15, 15,  3,  2,  4]),
#  array([17, 12,  8, 17, 18]),
#  array([15, 16, 13,  7, 14]),
#  array([ 4, 15, 11, 18,  2]),
#  array([12,  0, 11, 14, 16]),
#  array([ 7, 12,  7,  2,  6]),
#  array([17,  5,  2,  7,  0]),
#  array([ 9, 18,  1,  8, 17]),
#  array([14, 11, 12,  0,  1]),
#  array([ 9, 13, 17, 15,  6]),
#  array([ 6, 14, 15,  0,  0]),
#  array([14,  1,  5,  1, 14]),
#  array([11,  3, 10,  3, 10]),
#  array([17,  3, 14, 18, 14]),
#  array([13,  0, 14, 11,  2]),
#  array([12, 13,  4, 14, 14]),
#  array([18, 13, 15,  5, 12]),
#  array([15, 13, 11,  3, 16]),
#  array([ 3,  7, 12,  6, 11]),
#  array([5, 2, 6, 3, 1]),
#  array([ 8,  0, 11,  7,  5]),
#  array([16,  4, 15, 17, 18]),
#  array([3, 7, 7, 4, 4]),
#  array([ 5,  3, 15, 11, 16]),
#  array([ 7, 15,  0,  9,  2]),
#  array([ 3, 10, 17, 15, 15]),
#  array([13,  6, 12, 13, 17]),
#  array([ 9,  8, 14, 15,  6]),
#  array([ 2, 12, 18,  8,  7]),
#  array([ 4, 16, 12,  2, 14]),
#  array([11,  8, 13, 10, 13]),
#  array([14, 15, 17,  7,  5]),
#  array([14,  5, 10, 14, 14]),
#  array([18,  3,  9, 15, 15]),
#  array([ 8,  5,  3,  1, 10]),
#  array([ 4,  6, 16, 11,  9]),
#  array([15, 17,  6, 14,  6]),
#  array([ 4,  2,  7,  1, 15]),
#  array([ 7,  0,  6, 12,  6]),
#  array([ 0, 13, 15, 14, 14]),
#  array([18, 12,  3,  7,  7]),
#  array([ 6,  2, 16,  5, 17]),
#  array([ 2,  1, 12, 10, 18]),
#  array([9, 9, 8, 9, 9]),
#  array([ 8, 13,  4, 18,  7]),
#  array([11,  6,  3, 18,  1]),
#  array([ 7,  2, 18,  3, 17]),
#  array([ 0, 17,  5,  7, 13]),
#  array([18,  1,  8,  3,  6]),
#  array([ 6, 14,  0, 15, 12]),
#  array([ 4, 14, 12,  4, 16]),
#  array([14, 14, 18,  3, 10]),
#  array([5, 5, 1, 6, 5]),
#  array([12, 17, 17, 15, 11]),
#  array([17, 16, 17,  5,  9]),
#  array([ 9,  8, 10,  6, 18]),
#  array([14, 18,  3,  9, 15]),
#  array([ 7, 18,  8,  6,  0]),
#  array([ 5, 13, 12, 13, 11]),
#  array([ 6, 12, 13, 14, 17]),
#  array([ 4, 13,  3, 10, 12]),
#  array([4, 1, 6, 0, 2]),
#  array([ 6,  6,  7, 12, 17]),
#  array([ 5,  6,  3, 14,  2]),
#  array([18,  7, 11, 17,  4]),
#  array([ 0, 17,  8,  0, 14]),
#  array([10,  0,  3, 17, 12]),
#  array([ 6, 14,  1,  2, 14]),
#  array([5, 7, 7, 5, 7]),
#  array([ 2,  8, 11, 16,  6]),
#  array([18, 10, 13, 18,  2]),
#  array([ 2,  1, 15,  3,  9]),
#  array([13,  8,  8,  0, 17]),
#  array([ 7, 14, 18,  2, 16]),
#  array([ 5,  9, 16, 17,  2]),
#  array([17,  8, 11,  6,  6]),
#  array([13, 13, 18,  3, 14]),
#  array([ 5,  0, 13,  4, 11]),
#  array([13, 15, 17, 11,  7]),
#  array([12, 14, 11,  6,  3]),
#  array([9, 5, 3, 7, 3]),
#  array([16,  6, 11,  1,  4]),
#  array([ 5,  4, 14, 17, 14]),
#  array([18,  2, 12,  1,  7]),
#  array([15, 15,  6,  5, 14]),
#  array([ 4, 16, 14, 18,  8]),
#  array([ 4, 10,  3,  3,  2]),
#  array([ 0, 14,  5,  1, 11]),
#  array([ 7,  8,  6, 14, 11]),
#  array([ 2,  1, 17, 11, 10]),
#  array([ 5, 17,  8, 18,  9]),
#  array([ 9,  9, 14, 15, 11]),
#  array([ 2, 10, 17, 14, 14]),
#  array([ 5,  7,  2,  7, 13]),
#  array([14, 10, 10,  8,  9]),
#  array([17,  2, 11,  5, 12]),
#  array([10,  5,  4, 14,  2]),
#  array([10, 14, 14,  5, 14]),
#  array([ 1, 17,  1,  0,  3]),
#  array([ 4,  4,  2, 14, 11]),
#  array([ 8, 17,  1, 16, 12]),
#  array([ 4, 14,  4, 12, 12]),
#  array([12,  3,  3,  7,  2]),
#  array([ 9,  1, 18,  8, 14]),
#  array([ 5, 16, 14,  5,  2]),
#  array([ 0,  2,  3, 18,  3]),
#  array([ 7,  9, 12,  6,  2]),
#  array([15, 18, 13,  5, 15]),
#  array([ 4,  2,  4, 17,  6]),
#  array([14,  6, 15, 11, 10]),
#  array([18,  3,  1,  8,  0]),
#  array([17, 17, 14, 10, 18]),
#  array([ 2,  8, 14,  5,  7]),
#  array([13, 13,  8,  3, 14]),
#  array([17,  8, 10,  6,  9]),
#  array([10,  0, 13, 12,  0]),
#  array([17,  0,  5,  5, 10]),
#  array([ 6, 14,  7, 10, 16]),
#  array([ 3,  3, 16,  3,  8]),
#  array([ 0,  2, 11,  4, 16]),
#  array([ 1, 14, 14, 15, 16]),
#  array([ 9, 16,  6,  9,  1]),
#  array([17,  8, 13,  7, 15]),
#  array([ 8, 11,  8,  3,  4]),
#  array([6, 3, 4, 0, 0]),
#  array([ 3, 14, 15,  2, 13]),
#  array([ 9, 10,  2,  3, 17]),
#  array([ 4, 11,  6,  3,  5]),
#  array([ 2,  2, 17, 10,  6]),
#  array([ 7,  2,  1, 14, 16]),
#  array([14,  7,  0,  4,  5]),
#  array([10, 11,  2, 13, 14]),
#  array([17,  5,  3,  2,  5]),
#  array([ 4,  7,  2,  4, 12]),
#  array([ 7, 18, 11, 12, 14]),
#  array([18,  9,  5,  3,  3]),
#  array([14, 16, 11,  9, 10]),
#  array([ 5,  8, 12, 18, 13]),
#  array([18, 11,  0,  6,  9]),
#  array([ 8, 11, 15,  6,  4]),
#  array([14,  8, 18, 17,  6]),
#  array([ 6,  5, 14, 18, 13]),
#  array([ 8, 16, 13, 14, 18]),
#  array([15,  7, 15, 12,  8]),
#  array([14,  3, 16,  7, 12]),
#  array([ 7,  8, 16, 14, 14]),
#  array([15,  6, 14, 12, 17]),
#  array([13,  7, 15,  0, 18]),
#  array([ 4,  3, 10,  7, 13]),
#  array([17, 14, 14,  8,  1]),
#  array([14,  7, 16, 14, 14]),
#  array([18,  0, 17, 12,  2]),
#  array([15, 16, 10,  7, 13]),
#  array([15,  8, 15, 12,  4]),
#  array([ 2,  2, 11, 18,  7]),
#  array([ 4,  8,  1, 15,  3]),
#  array([11,  8,  0, 11, 11]),
#  array([ 0, 14,  7,  8, 17]),
#  array([ 8, 16, 12, 18, 17]),
#  array([15,  2, 15,  9, 10]),
#  array([ 0, 13, 12,  6,  5]),
#  array([11, 11,  9,  4, 15]),
#  array([16,  8, 10,  3, 14]),
#  array([10,  2,  1, 18, 13]),
#  array([14, 14,  2, 16, 17]),
#  array([12,  5, 16, 17, 16]),
#  array([ 8, 18,  1, 14, 16]),
#  array([10,  2,  4, 15,  9]),
#  array([18, 17,  9,  5, 13]),
#  array([13, 16, 17, 16, 15]),
#  array([ 7, 12,  9,  2, 13]),
#  array([ 2,  1, 13, 14,  3]),
#  array([8, 3, 3, 8, 4]),
#  array([14,  7, 16, 15, 14]),
#  array([16,  0, 10,  6,  5]),
#  array([8, 2, 1, 7, 2]),
#  array([12,  8, 11, 12, 15]),
#  array([ 5,  5, 14,  4, 12]),
#  array([16,  7,  1, 10,  9]),
#  array([13, 12, 12,  8, 10]),
#  array([14,  2,  7,  2, 13]),
#  array([13, 18, 10,  4,  6]),
#  array([ 9, 10,  5, 11,  6]),
#  array([ 6, 14, 15,  9,  3]),
#  array([ 1,  1, 14,  5,  1]),
#  array([13,  2, 12,  6, 12]),
#  array([ 3,  5,  1,  7, 14]),
#  array([14, 12,  0, 12, 16]),
#  array([14, 18,  1, 14, 14]),
#  array([ 3, 17,  3, 14, 17]),
#  array([11,  6, 11,  6, 12]),
#  array([ 6,  3,  9, 17, 14]),
#  array([14,  4, 11,  2,  7]),
#  array([13, 15,  5, 16, 15]),
#  array([ 6, 14,  2, 14,  6]),
#  array([ 7, 11,  3,  0,  8]),
#  array([ 5, 12,  8, 10,  4]),
#  array([14, 13,  2,  4, 14]),
#  array([ 7, 15,  4, 13, 16]),
#  array([ 4,  8,  1, 14,  4]),
#  array([ 4, 10,  8,  7, 14]),
#  array([ 8,  6, 11, 17, 18]),
#  array([17,  5,  5,  2,  4]),
#  array([ 3, 17, 16,  8, 12]),
#  array([18,  6,  4,  4, 18]),
#  array([ 2,  9,  0,  0, 13]),
#  array([ 4,  3, 13,  6,  3]),
#  array([ 5,  1, 13, 14, 17]),
#  array([ 2, 18,  8,  6,  3]),
#  array([ 4,  5,  6, 16,  1]),
#  array([2, 2, 3, 8, 8]),
#  array([14,  8, 11, 12,  7]),
#  array([ 7,  0, 14, 10, 14]),
#  array([ 3,  9, 17, 14, 13]),
#  array([12, 10,  8, 13, 11]),
#  array([17,  1,  9, 10,  7]),
#  array([11,  6,  1, 15, 14]),
#  array([ 0, 14, 11,  0,  4]),
#  array([13,  5,  2,  9, 13]),
#  array([ 4, 12, 14, 13,  1]),
#  array([11,  2, 11, 14,  0]),
#  array([ 1,  5,  1, 12,  7]),
#  array([ 3, 10, 15,  1, 14]),
#  array([ 7, 10, 11,  7,  9]),
#  array([ 7, 12, 10, 13,  3]),
#  array([ 4, 15,  5, 12, 17]),
#  array([ 9,  5, 10, 14,  1]),
#  array([16, 13, 15, 13, 15]),
#  array([ 0, 10, 14, 11,  2]),
#  array([ 0, 12,  5, 14, 13]),
#  array([ 7,  3, 11, 13,  5]),
#  array([ 8,  3, 17, 14, 10]),
#  array([17,  5,  5,  3, 16]),
#  array([ 9,  0,  0, 18,  3]),
#  array([18,  3, 16,  0,  6]),
#  array([17,  2, 15, 14, 15]),
#  array([6, 8, 8, 8, 8]),
#  array([13, 14, 10, 11,  3]),
#  array([13,  0,  0, 10,  1]),
#  array([1, 2, 7, 6, 2]),
#  array([14, 17, 17, 11,  6]),
#  array([ 2, 13,  0, 16,  3]),
#  array([14, 16,  3,  7,  0]),
#  array([ 8, 14, 10, 17,  2]),
#  array([ 3, 14,  0,  2,  3]),
#  array([11,  8,  4, 17,  7]),
#  array([15, 16,  3, 14,  8]),
#  array([12,  6,  6,  6, 17]),
#  array([ 1,  7, 14, 18, 11]),
#  array([10, 10,  6, 11, 12]),
#  array([ 4, 13, 18, 12,  7]),
#  array([ 8,  9, 13, 14,  6]),
#  array([12, 13,  5, 14,  6]),
#  array([ 6, 16, 18,  5,  9]),
#  array([ 5, 17,  9,  3, 13]),
#  array([14, 16, 14,  8, 14]),
#  array([14,  8, 16,  2, 12]),
#  array([11,  8, 10, 18,  1]),
#  array([12,  5, 12, 14, 11]),
#  array([10, 14,  2, 14,  2]),
#  array([ 0, 12, 18,  7,  4]),
#  array([ 1,  1, 11,  5, 13]),
#  array([ 0,  8, 12, 18, 17]),
#  array([17,  5,  2,  0,  0]),
#  array([10,  9, 12,  1, 15]),
#  array([ 6, 18,  4,  7,  1]),
#  array([0, 7, 6, 0, 5]),
#  array([11,  4, 16, 16,  6]),
#  array([ 1,  0,  3, 11,  7]),
#  array([13,  7,  2, 10, 14]),
#  array([13, 18,  6,  2, 10]),
#  array([14, 14, 15,  2, 10]),
#  array([ 1,  5, 10, 15,  4]),
#  array([1, 4, 7, 8, 0]),
#  array([12, 14, 18,  4,  7]),
#  array([ 8,  7,  6,  8, 11]),
#  array([11,  7, 15,  0,  8]),
#  array([8, 1, 3, 5, 0]),
#  array([ 1,  7,  9,  6, 11]),
#  array([ 8, 15, 10,  4,  1]),
#  array([14,  0,  4,  3, 18]),
#  array([ 4, 18,  9, 18, 15]),
#  array([ 8, 12,  3,  9,  9]),
#  array([15,  3, 12,  3, 13]),
#  array([18, 10, 18, 14,  2]),
#  array([3, 4, 8, 1, 2]),
#  array([ 8,  1, 14,  6, 17]),
#  array([11, 16,  1,  7,  0]),
#  array([10,  5,  0,  8,  9]),
#  array([12, 10, 12, 16,  2]),
#  array([18, 16,  4,  4,  5]),
#  array([15,  2, 14, 13,  2]),
#  array([13,  9, 18, 15,  5]),
#  array([ 0,  3, 16,  3,  1]),
#  array([ 5,  2, 10, 18, 12]),
#  array([18, 18, 12,  3, 12]),
#  array([16, 11, 18,  3, 13]),
#  array([ 6, 16,  6,  5,  3]),
#  array([12, 18, 13, 13, 14]),
#  array([17,  2,  3,  6, 16]),
#  array([12,  6, 12, 14,  9]),
#  array([10, 11, 12,  5,  0]),
#  array([ 3, 11, 18, 10, 13]),
#  array([ 2,  0, 17, 15, 18]),
#  array([13,  9,  9, 12,  7]),
#  array([10, 16, 14, 17,  6]),
#  array([ 6,  4,  6,  2, 13]),
#  array([14,  6, 18,  9,  9]),
#  array([ 6, 16,  5,  3,  2]),
#  array([ 4, 14,  2,  2,  1]),
#  array([ 4, 10,  4, 15, 14]),
#  array([15,  6,  8,  0,  2]),
#  array([ 0, 12,  5,  6,  1]),
#  array([13,  8,  6, 16,  0]),
#  array([ 6, 15, 11, 17, 17]),
#  array([ 0, 11, 17, 12,  9]),
#  array([14,  9, 12,  0,  7]),
#  array([ 5,  8,  9, 12, 10]),
#  array([14,  3,  8, 13,  5]),
#  array([ 1, 16, 14,  9,  1]),
#  array([14,  9, 13, 10,  5]),
#  array([14,  1, 17,  2,  8]),
#  array([17, 11,  2, 15,  2]),
#  array([ 7,  3, 15, 14, 14]),
#  array([14, 13, 16,  2,  4]),
#  array([ 7,  4,  6,  3, 14]),
#  array([ 4,  5,  5, 12,  1]),
#  array([ 3, 14, 15,  9, 14]),
#  array([17, 15,  0,  2, 15]),
#  array([14, 12,  5,  3,  4]),
#  array([11, 15,  1,  6,  0]),
#  array([16,  2, 14, 11, 17]),
#  array([ 4,  4, 16, 15,  3]),
#  array([ 5, 15,  6,  3,  0]),
#  array([ 2,  9, 12, 11,  5]),
#  array([15,  9, 18,  8,  6]),
#  array([11,  2, 16, 11, 14]),
#  array([ 8, 15,  8,  6,  8]),
#  array([ 9,  0,  1,  4, 14]),
#  array([ 4, 11,  0, 18,  8]),
#  array([16, 18,  8,  0,  3]),
#  array([ 8,  1,  3,  1, 10]),
#  array([ 2, 14,  1, 13, 14]),
#  array([13,  3, 18, 13,  0]),
#  array([13, 10, 14,  2, 11]),
#  array([ 4, 13, 14,  6, 14]),
#  array([ 7, 16,  4, 14,  4]),
#  array([14, 14, 12, 17,  8]),
#  array([ 4,  8, 16, 17, 10]),
#  array([13,  1,  3,  6,  6]),
#  array([ 2,  7,  0, 15, 16]),
#  array([15,  0, 18, 13,  0]),
#  array([ 4,  5,  9, 10, 18]),
#  array([17,  1,  2,  5, 14]),
#  array([12,  7, 17, 18, 18]),
#  array([ 9,  5,  8,  3, 17]),
#  array([ 6, 14,  3, 15,  1]),
#  array([ 5, 12, 13, 11,  1]),
#  array([11, 11, 15, 17, 11]),
#  array([12,  5, 11, 13,  8]),
#  array([ 4,  4,  2,  9, 14]),
#  array([14, 14, 14,  3,  5]),
#  array([18, 10, 16,  4, 15]),
#  array([14, 11, 14,  9, 16]),
#  array([ 7, 16,  2,  2, 16]),
#  array([14,  7, 11,  6, 13]),
#  array([ 5, 11,  6,  7,  1]),
#  array([12,  8,  0,  5,  5]),
#  array([ 5,  6, 10, 10,  8]),
#  array([ 9, 18, 15,  5, 14]),
#  array([ 0, 14, 17,  1,  6]),
#  array([ 9,  1,  8,  5, 18]),
#  array([12, 14,  0, 17, 18]),
#  array([ 1,  9, 10, 14,  4]),
#  array([ 9,  7, 15,  8,  9]),
#  array([18,  5, 17,  6, 15]),
#  array([ 3, 12,  3, 10,  3]),
#  array([12,  8, 17,  4, 11]),
#  array([ 2, 18,  8, 10, 17]),
#  array([ 0,  6, 17,  2,  5]),
#  array([ 5, 14, 14, 14, 17]),
#  array([12, 10, 16, 11, 18]),
#  array([ 3,  3, 18,  0, 13]),
#  array([ 4, 14, 12,  4, 14]),
#  array([ 0, 16, 17,  5,  1]),
#  array([16, 12,  4,  0,  3]),
#  array([12,  9,  6, 11,  7]),
#  array([ 3,  4, 14,  8, 17]),
#  array([14,  1, 11, 11, 14]),
#  array([12, 15,  0,  0, 17]),
#  array([ 3,  6, 15, 14, 15]),
#  array([14,  5, 13, 10,  7]),
#  array([11, 15,  5,  4,  0]),
#  array([16,  2,  8, 14, 14]),
#  array([10, 11, 17,  1,  2]),
#  array([ 9,  6, 17,  8, 14]),
#  array([18, 16,  5, 14, 18]),
#  array([15, 12,  0, 18, 17]),
#  array([ 6, 14,  4,  3, 14]),
#  array([ 6,  1,  0, 11,  1]),
#  array([ 9,  0, 14,  7, 14]),
#  array([ 0,  7, 12,  2,  6]),
#  array([7, 2, 9, 5, 8]),
#  array([ 2,  4, 13,  7, 13]),
#  array([12, 14,  8,  1, 14]),
#  array([10, 14, 14, 13, 13]),
#  array([ 3,  5, 12, 14, 17]),
#  array([14,  2, 17, 17,  3]),
#  array([ 9,  0,  0, 14,  5]),
#  array([ 9,  1,  8,  6, 18]),
#  array([0, 3, 1, 9, 8]),
#  array([ 9,  4, 11,  8, 14]),
#  array([ 8, 11, 14,  3,  1]),
#  array([ 5, 16, 14, 15, 13]),
#  array([16,  3,  0, 11, 14]),
#  array([ 9, 14, 13,  9,  6]),
#  array([ 6, 18,  4,  1, 11]),
#  array([11, 17, 15, 16,  1]),
#  array([ 8, 11,  8,  0, 18]),
#  array([ 1, 14, 16,  5, 16]),
#  array([ 8,  8, 11,  0, 16]),
#  array([12, 16, 14,  3,  1]),
#  array([ 1,  0,  9, 14, 14]),
#  array([14, 11,  6,  7,  6]),
#  array([18,  1,  1, 14, 13]),
#  array([ 8,  2,  7, 12,  9]),
#  array([17, 14, 14,  2,  9]),
#  array([ 4, 12,  2,  3, 16]),
#  array([ 8, 11, 11, 15,  2]),
#  array([13, 13, 12,  0, 13]),
#  array([17, 11, 12,  4,  3]),
#  array([16, 17,  8, 14,  6]),
#  array([ 1, 11,  7, 17,  9]),
#  array([ 9,  7, 11, 10, 14]),
#  array([ 0,  0,  9,  3, 14]),
#  array([10,  3, 14,  4,  4]),
#  array([15, 12, 12,  1, 14]),
#  array([ 0,  3, 13,  4, 15]),
#  array([15, 12, 13, 14,  0]),
#  array([18,  3, 12,  6,  5]),
#  array([15,  8, 10,  9, 10]),
#  array([13,  4,  5,  7,  1]),
#  array([10,  6,  9, 17, 14]),
#  array([17,  8,  4,  6, 14]),
#  array([17,  3, 11,  3,  2]),
#  array([12, 18,  2,  1,  1]),
#  array([ 9,  7, 14, 18,  1]),
#  array([8, 2, 3, 0, 5]),
#  array([16, 11,  4,  6,  2]),
#  array([13,  4, 14,  2, 17]),
#  array([ 9, 16,  4, 13, 14]),
#  array([12, 14, 12,  4, 10]),
#  array([10,  2, 12,  9,  5]),
#  array([ 3,  1, 13, 14,  6]),
#  array([ 1,  1, 14, 12,  2]),
#  array([ 1,  7, 17,  6,  4]),
#  array([ 7,  2, 14,  8, 14]),
#  array([ 7,  1, 17, 15, 14]),
#  array([ 7, 16, 13, 10, 10]),
#  array([8, 9, 8, 7, 1]),
#  array([12, 18,  3,  7, 11]),
#  array([ 1,  6,  5, 12,  0]),
#  array([ 1,  7, 11, 14,  9]),
#  array([13, 15, 13, 18,  3]),
#  array([ 4, 17, 15, 13, 10]),
#  array([17,  7,  8,  7, 17]),
#  array([ 3, 11,  1, 12, 11]),
#  array([ 5,  4, 18,  4, 11]),
#  array([ 6, 14, 14,  5,  1]),
#  array([ 8, 12,  8, 12,  7]),
#  array([ 1, 10, 14, 18,  5]),
#  array([3, 0, 2, 2, 5]),
#  array([ 9, 17, 16,  8, 16]),
#  array([ 3, 15,  6, 11, 13]),
#  array([14,  2, 16, 16, 14]),
#  array([18,  8, 14, 11,  8]),
#  array([ 1,  4,  6, 18,  3]),
#  array([16, 13,  2,  5, 11]),
#  array([17, 10,  4, 10,  7]),
#  array([15, 18, 11,  4,  3]),
#  array([11, 15, 16,  5,  4]),
#  array([ 8, 14, 13, 14, 14]),
#  array([10, 11,  7,  1, 11]),
#  array([13,  6, 13,  2, 17]),
#  array([14, 14, 11,  6,  7]),
#  array([14,  9, 18, 11, 10]),
#  array([13, 18,  8,  1,  8]),
#  array([14,  5,  9, 18,  7]),
#  array([15, 12,  0, 15, 13]),
#  array([14,  1,  1,  4, 10]),
#  array([16,  9, 16, 16,  6]),
#  array([16, 17, 18,  2, 14]),
#  array([18, 11,  9, 14,  5]),
#  array([13, 17,  6,  7,  7]),
#  array([ 2,  5,  2, 11, 11]),
#  array([ 2, 11, 15,  3, 12]),
#  array([ 3, 14,  5,  1,  0]),
#  array([ 9, 10, 14, 10,  7]),
#  array([15, 13, 12,  3,  3]),
#  array([13, 13, 11, 13,  4]),
#  array([11,  5,  3,  1, 11]),
#  array([14,  5, 11, 11,  0]),
#  array([11,  5,  3,  8, 17]),
#  array([10,  7,  8,  7, 17]),
#  array([15, 17, 14, 10,  6]),
#  array([6, 9, 7, 4, 5]),
#  array([12,  1,  9, 18,  4]),
#  array([ 7, 10,  1,  7, 15]),
#  array([ 5,  9, 18, 16, 16]),
#  array([ 7,  4, 11,  0, 15]),
#  array([ 1,  7,  2, 16, 10]),
#  array([ 6, 14,  3,  4, 13]),
#  array([17,  2,  2, 14,  2]),
#  array([ 0,  8, 10, 12, 11]),
#  array([12, 15,  5,  8,  3]),
#  array([ 9,  6,  9,  8, 10]),
#  array([ 2,  0,  9, 16,  2]),
#  array([10, 16,  8, 11,  3]),
#  array([16,  6,  7, 14, 17]),
#  array([ 4, 13, 10, 12, 10]),
#  array([ 6, 12, 13,  8,  2]),
#  array([10,  4, 13,  4, 15]),
#  array([ 9,  4,  4,  4, 13]),
#  array([ 4,  0, 14,  7,  1]),
#  array([ 3,  1,  0,  3, 13]),
#  array([ 9, 14, 17,  9, 15]),
#  array([11,  8, 14, 10,  4]),
#  array([ 6, 12, 11,  5, 14]),
#  array([12, 12,  9,  5, 13]),
#  array([ 7, 16,  3, 18, 13]),
#  array([15, 10,  2, 17, 14]),
#  array([ 7, 18,  3, 18,  1]),
#  array([14,  7,  2,  3,  9]),
#  array([ 5, 15,  8,  9,  5]),
#  array([ 3, 18, 17, 12, 15]),
#  array([9, 9, 5, 4, 2]),
#  array([ 8,  8, 14,  0, 17]),
#  array([ 1, 16,  0,  7, 16]),
#  array([17, 14, 11, 17,  3]),
#  array([ 4,  2, 13,  6,  0]),
#  array([ 1, 14,  1,  8, 11]),
#  array([ 1, 18, 10,  0, 10]),
#  array([ 1, 15, 10,  2, 12]),
#  array([ 3,  3,  4, 16,  9]),
#  array([14, 12, 14,  0,  4]),
#  array([ 3,  7, 14,  9,  5]),
#  array([ 6, 11, 10, 17, 14]),
#  array([15, 17,  9, 16, 15]),
#  array([11, 12,  6, 14,  2]),
#  array([2, 2, 8, 0, 0]),
#  array([14, 11,  9,  6, 12]),
#  array([16,  2,  4, 10, 15]),
#  array([ 4, 15,  0, 12, 10]),
#  array([15,  0,  2, 12, 14]),
#  array([18,  2, 10,  8,  0]),
#  array([ 5,  5, 16, 15,  2]),
#  array([1, 5, 9, 3, 0]),
#  array([ 7,  0,  4, 14,  9]),
#  array([ 8,  2, 13,  8, 13]),
#  array([15, 12, 16, 14, 15]),
#  array([12,  8,  0, 16,  9]),
#  array([14, 12,  4, 18, 15]),
#  array([ 6,  7,  7, 13,  2]),
#  array([17, 11, 12, 17,  7]),
#  array([ 0,  8, 12,  3,  6]),
#  array([17,  6, 17, 14, 15]),
#  array([ 6,  8,  0, 16, 18]),
#  array([14, 18,  6, 14, 15]),
#  array([10, 14, 15, 16,  0]),
#  array([ 4,  7, 14, 14, 13]),
#  array([12,  6,  2,  0,  8]),
#  array([12,  0,  2,  5, 16]),
#  array([16,  9,  9,  8, 15]),
#  array([ 4,  1, 15, 17, 10]),
#  array([10, 15,  6,  3, 17]),
#  array([ 0, 16,  8,  1,  6]),
#  array([14, 17,  8, 13, 14]),
#  array([13,  2,  3,  5,  9]),
#  array([12,  5,  6, 12, 14]),
#  array([10,  5, 17,  2,  3]),
#  array([17,  0,  8, 14, 14]),
#  array([13, 11,  8,  1,  3]),
#  array([13,  3, 13, 10, 12]),
#  array([ 1, 10,  7, 15, 16]),
#  array([ 8,  0, 12,  2,  9]),
#  array([17,  9, 14,  4,  3]),
#  array([17, 14,  9,  1, 18]),
#  array([18, 15, 16,  1,  9]),
#  array([8, 2, 6, 0, 7]),
#  array([ 4,  5,  3, 15,  1]),
#  array([18, 17,  0,  9,  2]),
#  array([14, 10, 12, 12, 14]),
#  array([ 6, 14, 10,  2, 12]),
#  array([11, 16, 17,  9, 15]),
#  array([ 8,  4, 16, 10,  4]),
#  array([ 3, 18, 16, 16, 11]),
#  array([18,  5, 13, 14, 13]),
#  array([ 2,  5,  2,  1, 15]),
#  array([ 1, 15,  2, 14, 14]),
#  array([13, 12,  9, 16,  7]),
#  array([ 9,  7, 10, 17,  1]),
#  array([18,  0,  2,  1,  4]),
#  array([ 3, 17,  5, 17,  3]),
#  array([10,  4,  4,  5, 17]),
#  array([16, 16, 13, 14,  4]),
#  array([ 7, 17, 17, 11,  8]),
#  array([ 5, 11, 13,  8, 18]),
#  array([17,  2, 12, 12,  3]),
#  array([11, 14,  8, 14,  7]),
#  array([ 2,  5, 10,  2, 15]),
#  array([ 4,  9, 13, 17,  5]),
#  array([10, 12, 17, 13, 15]),
#  array([12, 13,  0,  8,  0]),
#  array([ 6, 10,  1,  0, 13]),
#  array([11, 12,  1,  6,  7]),
#  array([18,  0, 18, 10,  6]),
#  array([10, 17,  8, 13, 14]),
#  array([16,  7, 14,  8, 16]),
#  array([ 5, 12, 14, 12, 10]),
#  array([18, 12, 10, 14, 14]),
#  array([18,  9,  1, 13,  1]),
#  array([ 5,  7, 16, 13,  0]),
#  array([16, 14, 13, 18, 14]),
#  array([14, 13,  0,  2,  6]),
#  array([ 1, 12,  0, 16,  4]),
#  array([14,  7, 13, 17,  5]),
#  array([ 3, 13,  8, 18,  5]),
#  array([ 8,  4, 11,  6, 12]),
#  array([ 4, 15, 16,  8, 14]),
#  array([ 4, 11, 14,  6,  2]),
#  array([10, 15, 15, 12,  1]),
#  array([ 4,  7,  2, 16,  4]),
#  array([14, 12,  2,  4, 13]),
#  array([12, 16,  3,  1, 13]),
#  array([ 0, 18,  8, 14,  6]),
#  array([ 1, 14, 18,  2,  3]),
#  array([15, 13,  1,  4,  1]),
#  array([14,  0,  7, 18,  5]),
#  array([11,  0,  0,  7, 14]),
#  array([ 7, 14,  8,  0, 11]),
#  array([ 9,  9, 15, 18,  7]),
#  array([15,  9, 16,  1,  6]),
#  array([7, 9, 7, 7, 1]),
#  array([10, 14,  1,  0, 10]),
#  array([ 3, 13, 12, 14,  2]),
#  array([16,  5, 10,  4, 13]),
#  array([17, 13,  8, 18, 13]),
#  array([ 3,  5, 16,  9, 15]),
#  array([14,  6, 11, 15,  4]),
#  array([13,  5,  3,  7, 11]),
#  array([11,  0,  0,  6, 14]),
#  array([ 6, 18, 15,  9, 14]),
#  array([0, 3, 0, 3, 5]),
#  array([ 1,  6, 14,  3,  5]),
#  array([10,  1, 14,  9, 14]),
#  array([16, 10,  8, 11,  9]),
#  array([ 2,  8,  6, 14,  6]),
#  array([ 7, 13, 17, 15, 10]),
#  array([ 1,  9, 12, 13, 11]),
#  array([ 4,  6,  0,  3, 18]),
#  array([13,  7, 11,  3,  6]),
#  array([ 3, 16,  9,  9, 16]),
#  array([14,  2,  8, 15, 18]),
#  array([ 8, 10, 14,  3,  3]),
#  array([ 5,  4,  1,  2, 18]),
#  array([14,  3, 16,  3, 12]),
#  array([8, 8, 6, 2, 3]),
#  array([16,  2, 17,  0, 13]),
#  array([14, 14, 11, 17,  1]),
#  array([ 3, 17,  9,  0, 10]),
#  array([16,  4, 18, 14, 10]),
#  array([17,  1,  5,  7, 11]),
#  array([18,  2, 14,  4, 13]),
#  array([18,  8, 13,  8, 16]),
#  array([ 9,  9,  8, 14, 10]),
#  array([13, 13, 12,  1,  6]),
#  array([ 9, 13, 16,  6, 14]),
#  array([ 5, 18,  0, 17,  2]),
#  array([17, 10, 13, 18, 12]),
#  array([ 8, 11, 16,  4, 10]),
#  array([14, 11,  8, 16, 18]),
#  array([12,  9, 14, 12,  1]),
#  array([ 2, 14, 14, 11,  1]),
#  array([ 8,  9, 11,  5,  5]),
#  array([6, 5, 9, 2, 8]),
#  array([16,  2,  6,  8, 16]),
#  array([ 1, 14,  5, 13, 17]),
#  array([ 3, 13, 11,  5,  8]),
#  array([ 6, 14,  3, 15, 14]),
#  array([ 9, 16,  1, 14, 14]),
#  array([ 3, 15, 13,  4,  7]),
#  array([1, 1, 7, 0, 0]),
#  array([ 1, 10,  7, 14, 14]),
#  array([9, 0, 0, 7, 9]),
#  array([ 0, 18, 12, 12, 12]),
#  array([ 3,  6,  7,  3, 13]),
#  array([ 2, 10, 12, 10, 13]),
#  array([14,  7,  8, 12,  7]),
#  array([18,  5,  9,  5,  3]),
#  array([ 1,  0,  8, 14, 14]),
#  array([10,  6, 10,  3, 10]),
#  array([11,  3,  8, 13,  0]),
#  array([ 2,  9, 16,  1, 16]),
#  array([17,  7, 10, 13,  4]),
#  array([15, 11,  3, 14, 12]),
#  array([18,  9,  9,  1, 12]),
#  array([15, 13,  2,  5, 11]),
#  array([14, 17,  8,  6,  1]),
#  array([10, 11, 12, 17,  3]),
#  array([14,  4, 14, 14,  0]),
#  array([ 9,  2, 14,  6,  0]),
#  array([ 0, 15, 11, 15, 14]),
#  array([12, 16, 14, 13,  4]),
#  array([ 5, 16,  4,  5, 13]),
#  array([ 3, 12,  8,  9,  1]),
#  array([12, 11,  0, 12,  2]),
#  array([ 1, 17, 14, 12,  4]),
#  array([13, 11,  7,  1, 17]),
#  array([ 8,  5, 12,  7,  1]),
#  array([ 1,  5,  6, 10,  3]),
#  array([17,  4,  7,  3, 13]),
#  array([10, 14, 12,  3,  1]),
#  array([ 7, 14,  3, 13, 16]),
#  array([ 0, 10, 14,  5, 12]),
#  array([16,  0, 14,  5, 10]),
#  array([13,  9, 17, 15, 14]),
#  array([3, 5, 2, 9, 5]),
#  array([ 4, 12, 10,  1, 15]),
#  array([ 3, 13, 11, 11, 11]),
#  array([ 6, 12, 10,  8, 13]),
#  array([12, 15, 14, 17, 14]),
#  array([15, 13,  9,  1, 16]),
#  array([ 1, 13, 17,  9, 14]),
#  array([6, 7, 5, 1, 3]),
#  array([11, 11, 14, 17, 14]),
#  array([ 1, 14,  9, 17,  9]),
#  array([ 6,  8,  0,  1, 11]),
#  array([ 4, 17, 10, 14,  2]),
#  array([12, 16,  2,  4,  6]),
#  array([11,  1,  4,  2, 17]),
#  array([13,  2, 11,  9,  6]),
#  array([15, 14, 14, 16, 18]),
#  array([11, 15,  3, 16, 14]),
#  array([ 8, 16,  9, 14, 17]),
#  array([10, 11, 10,  4,  0]),
#  array([14,  7, 15,  1, 10]),
#  array([ 8,  0, 15, 12,  4]),
#  array([15, 17,  0, 17, 15]),
#  array([3, 5, 1, 9, 6]),
#  array([14, 18,  7,  8, 17]),
#  array([13,  8, 18, 11, 17]),
#  array([14, 17, 14,  2, 11]),
#  array([11,  4, 14, 10,  3]),
#  array([ 1,  2, 15,  8, 14]),
#  array([5, 4, 1, 3, 1]),
#  array([13, 18, 11,  6,  0]),
#  array([15, 16, 14,  3, 10]),
#  array([ 8,  0, 18, 14,  6]),
#  array([18, 16, 14,  4, 11]),
#  array([ 8, 14, 16, 18,  8]),
#  array([ 9, 14, 14, 10,  5]),
#  array([12, 17, 17,  0, 15]),
#  array([ 0, 15,  0, 18,  6]),
#  array([15, 12, 13,  0, 10]),
#  array([11,  9, 15, 12,  9]),
#  array([15, 13, 10,  6,  4]),
#  array([ 3,  4, 13,  4, 18]),
#  array([13, 16,  9, 11,  4]),
#  array([14, 13, 18,  0, 17]),
#  array([ 2, 14,  8,  1,  5]),
#  array([ 1,  5,  5, 17, 17]),
#  array([ 5, 12, 15,  2,  5]),
#  array([14,  3, 14,  6,  7]),
#  array([ 2, 11,  8,  1,  4]),
#  array([ 0,  3, 15,  0, 13]),
#  array([18,  1,  0, 18, 18]),
#  array([ 9, 11, 14, 17,  2]),
#  array([11, 10, 18,  8,  6]),
#  array([ 3, 13, 14, 15,  9]),
#  array([15,  0,  9, 16,  5]),
#  array([17, 17,  7, 13,  3]),
#  array([17,  9,  8, 14,  2]),
#  array([11, 12,  5, 13, 12]),
#  array([12, 11,  7, 17,  4]),
#  array([10,  9, 16, 14, 18]),
#  ...]

# %%
targets_enc_1 = np.array(targets_enc) + 1

# %%
targets_enc_1
# Out:
# array([[15, 12,  1, 15,  7],
#        [ 4,  2,  6, 15, 12],
#        [10, 11, 12, 19, 18],
#        ...,
#        [14,  1,  2,  8, 16],
#        [12,  6,  9, 11, 19],
#        [ 6, 10,  3,  3, 14]])

# %%
# print(len(lbl_enc.classes_))    ### 19 unique classes hain.

# %%
train_imgs, test_imgs, train_targets, test_targets, _, test_orig_targets = model_selection.train_test_split(image_files, targets_enc, targets_orig, test_size=0.1, random_state=42)

# %%
len(train_imgs)
# len(image_files)
# len(targets_enc)
# len(targets_orig)
len(test_imgs)
# len(test_imgs)
# len(test_orig_targets)
# len(test_orig_targets)
# Out:
# 104

# %%
train_dataset = ClassificationDataset(image_paths=train_imgs, targets=train_targets, resize = (75, 300)) # resize = (height, width)

# %%
BATCH_SIZE = 8 
IMAGE_WIDTH = 300
IMAGE_HEIGHT = 75
NUM_WORKERS = 8
EPOCHS = 30

train_loader = torch.utils.data.DataLoader(train_dataset, batch_size = BATCH_SIZE,
                                           num_workers = NUM_WORKERS, shuffle = True)
# Out:
# /home/furqan/.pyenv/versions/3.8.5/lib/python3.8/site-packages/torch/utils/data/dataloader.py:474: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(

# %%
test_dataset = ClassificationDataset(test_imgs, test_targets, resize= (75, 300))

# %%
test_dataset = ClassificationDataset(
        image_paths = test_imgs,
        targets = test_targets, 
        resize = (IMAGE_HEIGHT, IMAGE_WIDTH),
    )

# %%
test_loader= torch.utils.data.DataLoader(test_dataset, batch_size= BATCH_SIZE, num_workers= NUM_WORKERS, shuffle=False)

# %%
train_dataset[935]["images"].shape
# Out:
# torch.Size([3, 75, 300])

# %%
train_dataset[935]["targets"].shape
# Out:
# torch.Size([5])

# %% [markdown]
# # Modeling

# %%
import torch
from torch import nn
from torch.nn import functional as F

# %%
class CaptchaModel(nn.Module):
    def __init__(self, num_chars):
        super(CaptchaModel, self).__init__()
        self.conv1 = nn.Conv2d(3, 128, kernel_size=(3, 6), padding=(1, 1))
        self.pool1 = nn.MaxPool2d(kernel_size= (2, 2))
        
        self.conv2 = nn.Conv2d(128, 64, kernel_size=(3, 6), padding=(1, 1))
        self.pool2 = nn.MaxPool2d(kernel_size= (2, 2))
        
        self.linear1 = nn.Linear(768, 64)  # linear1 ka jo 1st parameter hai wo dependent hai relu k output par. Yani relu krny k baad jo image ki shape hogi hme linear ka first dim us hisaab sy rkhna pary ga. 
        self.drop1 = nn.Dropout(0.2)
        
        self.gru = nn.GRU(64, 32, bidirectional=True, num_layers = 2, dropout=0.25, batch_first = True)
        self.output = nn.Linear(64, num_chars + 1)
        
    def forward(self, images, targets=None):  # images mean yha training data pass hoga. 
        bs, _,_, _ = images.size()
        x = F.relu(self.conv1(images))
        x = self.pool1(x)
        x = F.relu(self.conv2(x))
        x = self.pool2(x)
        x = x.permute(0, 3, 1, 2) # permute is used to manupulate dimensions in pytorch. 
        x = x.view(bs, x.size(1), -1)  # -1 mean, baki dimensions ko mila ka ak column bna do. so like it is used to reduce 4 dimensions into 2 dimensions. 
        # (1, 47, 768)
        x = F.relu(self.linear1(x))
        x = self.drop1(x)
        x, _ = self.gru(x) # yha dash ki jga par hidden state output return hota hai. 1st parameter me actual output return hota hai which u can feed into next layer. 
        x = self.output(x)
        x = x.permute(1, 0, 2)
        
        if targets is not None:
            log_probs = F.log_softmax(x, 2)
            input_lengths = torch.full(
                size=(bs,), fill_value=log_probs.size(0), dtype=torch.int32  # log_probs.size(0) : 0
            )  # there is only one value which is 47
            
            target_lengths = torch.full(
                size=(bs,), fill_value=targets.size(1), dtype=torch.int32
            )
            
            loss = nn.CTCLoss(blank=0)(
                log_probs, targets, input_lengths, target
            )
            return target_lengths
        return x

# %%
img = torch.rand((1, 3, 50, 200))
img.size()
# cm(img, torch.rand((1, 5)))
# Out:
# torch.Size([1, 3, 50, 200])

# %%
target = torch.randint(1, 20, (1, 5))
target
# target = torch.rand((1, 5))
# target
# Out:
# tensor([[ 4,  8,  1,  4, 10]])

# %%
cm = CaptchaModel(19)  # 19 is the length of target. i.e. there are 19 unique letters.

# %%
cm(img, target)   # yha par return hamesha forward k function me jo cheez return ho rhi hogi. VO return hoga.
# Out:
# tensor([5], dtype=torch.int32)

# %%
# torch.Size([1, 47, 64])

# %%
# torch.Size([47, 1, 20])
